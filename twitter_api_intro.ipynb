# %%
# !pip install requests
# Out:
# Requirement already satisfied: requests in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (2.28.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from requests) (2022.9.24)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from requests) (1.26.12)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from requests) (3.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from requests) (2.1.1)

# %%
import requests
import pandas as pd

with open('bearer_token.txt') as fp:
    BEARER_TOKEN = fp.read()

# %% [markdown]
#  # Requesting Data

# %% [markdown]
# `query` parameter is must. For more information: https://developer.twitter.com/en/docs/twitter-api/tweets/search/api-reference/get-tweets-search-recent

# %%
response = requests.get('https://api.twitter.com/2/tweets/search/recent?query=Tesla')
response.json()
# Out:
# {'title': 'Unauthorized',
#  'type': 'about:blank',
#  'status': 401,
#  'detail': 'Unauthorized'}

# %% [markdown]
# We need to include our bearer token for authorization - we add it to the request `headers`

# %%
headers = {'authorization': f'Bearer {BEARER_TOKEN}'}
response = requests.get('https://api.twitter.com/2/tweets/search/recent?query=Tesla', headers = headers)
response.json()
# Out:
# {'data': [{'edit_history_tweet_ids': ['1645207791890513920'],
#    'id': '1645207791890513920',
#    'text': "@memesus77 @tearsintherain1 @ALi3NKAT @StarshipDock @PryZmRuleZZ @TeslaDarth @Michaeldoge420 @QuantumFekT @IamCelineMarie @TheKatsKid1 @lottkaren54 @Lionelclone1 @safferpsyche @SpadersNFTs @AndreMillaire @Rajtwittz @DogeAccept @musicphantom69 @jewel_gardener @d1dave123 @dawnheartLRPS @sofakingdoge2nd @kym_head @YeshuaisSavior @PiaPanda96 @PleiadesPlZ @YadiraRussell9 @YOUniverse999 @MaximoBanksy @bugaloo_2 @13dogecoin @boozelee86 @h_artsNcrafts @MarshaW15161057 @codehurtsbrain @elonmusk @Tesla @Tesla_Megapack @Grimezsz @dogecoin @Nike @SpaceCrystalZ @historydefined @HistoryInPics @NelsonMandela @YourHomeMars @SpaceX Is everyone scheduled and excited for bear hug Thursday it's coming up ya know....\n\nSigh 😕 https://t.co/btJxNITJuH"},
#   {'edit_history_tweet_ids': ['1645207779123118080'],
#    'id': '1645207779123118080',
#    'text': '@SawyerMerritt @Tesla https://t.co/r0f31PhSxb'},
#   {'edit_history_tweet_ids': ['1645207775113523203'],
#    'id': '1645207775113523203',
#    'text': '@Nikola_Truth @blueskykites @TeslaUniverse_ @Tesla @WholeMarsBlog @Kristennetten @S4njuBajaj @teardowntitan @WestTeslarado @PauljHorton @atk0506 @WIsitlike @mundanemun @Amy_Sober @TeslaDiva99 @R6Alex @shortword @1stMarsColonist @CorySteuben @MadTorque @JhonnyOnasis @MobofJoggers @InchaustiRon 🥳🚀♥️'},
#   {'edit_history_tweet_ids': ['1645207772248653824'],
#    'id': '1645207772248653824',
#    'text': '@Tesla @elonmusk @NissanElectric @ford @Rivian @ENERGY @environmentca @cbc @CTVNews @JustinTrudeau @JoeBiden https://t.co/78LuPzk5k8'},
#   {'edit_history_tweet_ids': ['1645207760634626048'],
#    'id': '1645207760634626048',
#    'text': '@memesus77 @nachodelaheysus @ALi3NKAT @StarshipDock @PryZmRuleZZ @TeslaDarth @Michaeldoge420 @QuantumFekT @IamCelineMarie @TheKatsKid1 @lottkaren54 @Lionelclone1 @safferpsyche @SpadersNFTs @AndreMillaire @Rajtwittz @DogeAccept @musicphantom69 @jewel_gardener @d1dave123 @dawnheartLRPS @sofakingdoge2nd @kym_head @YeshuaisSavior @PiaPanda96 @PleiadesPlZ @YadiraRussell9 @YOUniverse999 @MaximoBanksy @bugaloo_2 @13dogecoin @boozelee86 @h_artsNcrafts @MarshaW15161057 @codehurtsbrain @elonmusk @Tesla @Tesla_Megapack @Grimezsz @dogecoin @Nike @SpaceCrystalZ @historydefined @HistoryInPics @NelsonMandela @YourHomeMars @SpaceX Lol 😝'},
#   {'edit_history_tweet_ids': ['1645207751646392320'],
#    'id': '1645207751646392320',
#    'text': 'RT @elonmusk: @DavidSacks @VivekGRamaswamy @GregAbbott_TX Yeah, wrong on many levels. Tesla is increasing production rapidly in Texas, Cali…'},
#   {'edit_history_tweet_ids': ['1645207748722798592'],
#    'id': '1645207748722798592',
#    'text': '@hyteckit @farzyness The big one with these Tesla cars that everybody seems to forget is to check the blinker fluid.'},
#   {'edit_history_tweet_ids': ['1645207748362084356'],
#    'id': '1645207748362084356',
#    'text': '@indigenoussista He originally brought the fight to Tesla on his own.  Then a Blk female HR filed her complaint after his lawyers case was set for settlement before he won in court.  She was in HR and did nothing the entire time but ignore the racist actions of the management team.'},
#   {'edit_history_tweet_ids': ['1645207743375220736'],
#    'id': '1645207743375220736',
#    'text': 'Tesla 人形機器人\n\nhttps://t.co/984T8usZB8'},
#   {'edit_history_tweet_ids': ['1645207738446651392'],
#    'id': '1645207738446651392',
#    'text': 'RT @SaycheeseDGTL: 😢 Former Tesla worker Owen Diaz was awarded $137M last year for dealing with racism on the job “The supervisor called hi…'}],
#  'meta': {'newest_id': '1645207791890513920',
#   'oldest_id': '1645207738446651392',
#   'result_count': 10,
#   'next_token': 'b26v89c19zqg8o3fqkd0rv6ra2sk0fs7i24robed7b0jh'}}

# %% [markdown]
#  we use `&` to string multiple parameters together.
#  - Include the creation daretime and detected language fields using the `tweet.fields` parameter.
#  - Currently limited number of tweets, we can increase with `max_results=100`
#
#  https://api.twitter.com/2/tweets/search/recent?query=Tesla<span style='background-color:#E7FFAC'>&tweet.fields=created_at,lang&max_results=100</span>

# %%
response = requests.get('https://api.twitter.com/2/tweets/search/recent?query=Tesla&tweet.fields=created_at,lang&max_results=100', headers = headers)
response.json()
# Out:
# {'data': [{'id': '1645207791890513920',
#    'lang': 'en',
#    'text': "@memesus77 @tearsintherain1 @ALi3NKAT @StarshipDock @PryZmRuleZZ @TeslaDarth @Michaeldoge420 @QuantumFekT @IamCelineMarie @TheKatsKid1 @lottkaren54 @Lionelclone1 @safferpsyche @SpadersNFTs @AndreMillaire @Rajtwittz @DogeAccept @musicphantom69 @jewel_gardener @d1dave123 @dawnheartLRPS @sofakingdoge2nd @kym_head @YeshuaisSavior @PiaPanda96 @PleiadesPlZ @YadiraRussell9 @YOUniverse999 @MaximoBanksy @bugaloo_2 @13dogecoin @boozelee86 @h_artsNcrafts @MarshaW15161057 @codehurtsbrain @elonmusk @Tesla @Tesla_Megapack @Grimezsz @dogecoin @Nike @SpaceCrystalZ @historydefined @HistoryInPics @NelsonMandela @YourHomeMars @SpaceX Is everyone scheduled and excited for bear hug Thursday it's coming up ya know....\n\nSigh 😕 https://t.co/btJxNITJuH",
#    'created_at': '2023-04-09T23:31:18.000Z',
#    'edit_history_tweet_ids': ['1645207791890513920']},
#   {'id': '1645207779123118080',
#    'lang': 'qme',
#    'text': '@SawyerMerritt @Tesla https://t.co/r0f31PhSxb',
#    'created_at': '2023-04-09T23:31:15.000Z',
#    'edit_history_tweet_ids': ['1645207779123118080']},
#   {'id': '1645207775113523203',
#    'lang': 'qme',
#    'text': '@Nikola_Truth @blueskykites @TeslaUniverse_ @Tesla @WholeMarsBlog @Kristennetten @S4njuBajaj @teardowntitan @WestTeslarado @PauljHorton @atk0506 @WIsitlike @mundanemun @Amy_Sober @TeslaDiva99 @R6Alex @shortword @1stMarsColonist @CorySteuben @MadTorque @JhonnyOnasis @MobofJoggers @InchaustiRon 🥳🚀♥️',
#    'created_at': '2023-04-09T23:31:14.000Z',
#    'edit_history_tweet_ids': ['1645207775113523203']},
#   {'id': '1645207772248653824',
#    'lang': 'qam',
#    'text': '@Tesla @elonmusk @NissanElectric @ford @Rivian @ENERGY @environmentca @cbc @CTVNews @JustinTrudeau @JoeBiden https://t.co/78LuPzk5k8',
#    'created_at': '2023-04-09T23:31:14.000Z',
#    'edit_history_tweet_ids': ['1645207772248653824']},
#   {'id': '1645207760634626048',
#    'lang': 'und',
#    'text': '@memesus77 @nachodelaheysus @ALi3NKAT @StarshipDock @PryZmRuleZZ @TeslaDarth @Michaeldoge420 @QuantumFekT @IamCelineMarie @TheKatsKid1 @lottkaren54 @Lionelclone1 @safferpsyche @SpadersNFTs @AndreMillaire @Rajtwittz @DogeAccept @musicphantom69 @jewel_gardener @d1dave123 @dawnheartLRPS @sofakingdoge2nd @kym_head @YeshuaisSavior @PiaPanda96 @PleiadesPlZ @YadiraRussell9 @YOUniverse999 @MaximoBanksy @bugaloo_2 @13dogecoin @boozelee86 @h_artsNcrafts @MarshaW15161057 @codehurtsbrain @elonmusk @Tesla @Tesla_Megapack @Grimezsz @dogecoin @Nike @SpaceCrystalZ @historydefined @HistoryInPics @NelsonMandela @YourHomeMars @SpaceX Lol 😝',
#    'created_at': '2023-04-09T23:31:11.000Z',
#    'edit_history_tweet_ids': ['1645207760634626048']},
#   {'id': '1645207751646392320',
#    'lang': 'en',
#    'text': 'RT @elonmusk: @DavidSacks @VivekGRamaswamy @GregAbbott_TX Yeah, wrong on many levels. Tesla is increasing production rapidly in Texas, Cali…',
#    'created_at': '2023-04-09T23:31:09.000Z',
#    'edit_history_tweet_ids': ['1645207751646392320']},
#   {'id': '1645207748722798592',
#    'lang': 'en',
#    'text': '@hyteckit @farzyness The big one with these Tesla cars that everybody seems to forget is to check the blinker fluid.',
#    'created_at': '2023-04-09T23:31:08.000Z',
#    'edit_history_tweet_ids': ['1645207748722798592']},
#   {'id': '1645207748362084356',
#    'lang': 'en',
#    'text': '@indigenoussista He originally brought the fight to Tesla on his own.  Then a Blk female HR filed her complaint after his lawyers case was set for settlement before he won in court.  She was in HR and did nothing the entire time but ignore the racist actions of the management team.',
#    'created_at': '2023-04-09T23:31:08.000Z',
#    'edit_history_tweet_ids': ['1645207748362084356']},
#   {'id': '1645207743375220736',
#    'lang': 'zh',
#    'text': 'Tesla 人形機器人\n\nhttps://t.co/984T8usZB8',
#    'created_at': '2023-04-09T23:31:07.000Z',
#    'edit_history_tweet_ids': ['1645207743375220736']},
#   {'id': '1645207738446651392',
#    'lang': 'en',
#    'text': 'RT @SaycheeseDGTL: 😢 Former Tesla worker Owen Diaz was awarded $137M last year for dealing with racism on the job “The supervisor called hi…',
#    'created_at': '2023-04-09T23:31:05.000Z',
#    'edit_history_tweet_ids': ['1645207738446651392']},
#   {'id': '1645207728627875843',
#    'lang': 'en',
#    'text': '@msaunby @KaramMacro @ParikPatelCFA @RobinWigg Yeah Tesla just seems like they are dogshit and plummeting every day. Get off Twitter @elonmusk  😂',
#    'created_at': '2023-04-09T23:31:03.000Z',
#    'edit_history_tweet_ids': ['1645207728627875843']},
#   {'id': '1645207725368803330',
#    'lang': 'en',
#    'text': '@elonmusk @WallStreetSilv will Tesla have a "government funded car company" added to it\'s twitter account?',
#    'created_at': '2023-04-09T23:31:02.000Z',
#    'edit_history_tweet_ids': ['1645207725368803330']},
#   {'id': '1645207720478294023',
#    'lang': 'en',
#    'text': '@wieslawawy @HankMeninga @Tesla @elonmusk I only buy clothes made in South Asia because they allow child labor. I think children make better clothes',
#    'created_at': '2023-04-09T23:31:01.000Z',
#    'edit_history_tweet_ids': ['1645207720478294023']},
#   {'id': '1645207710055407619',
#    'lang': 'en',
#    'text': '@teslamarge @DimaZeniuk @teslaownersSV @Tesla @elonmusk @TeslaNY @klwtts @WholeMarsBlog @DriveTeslaca @BrandonTSLA Ya, wheels can be changed just get me that truck asap.',
#    'created_at': '2023-04-09T23:30:59.000Z',
#    'edit_history_tweet_ids': ['1645207710055407619']},
#   {'id': '1645207707304034315',
#    'lang': 'es',
#    'text': 'RT @TeslaSynopsis: Tesla autopark\nhttps://t.co/B2s60FGWFu',
#    'created_at': '2023-04-09T23:30:58.000Z',
#    'edit_history_tweet_ids': ['1645207707304034315']},
#   {'id': '1645207706897113089',
#    'lang': 'en',
#    'text': 'RT @EvaFoxU: Tesla has installed 45,000 Supercharger stalls worldwide, greatly accelerating the pace of rollout in recent months ⚡️⚡️⚡️ Cha…',
#    'created_at': '2023-04-09T23:30:58.000Z',
#    'edit_history_tweet_ids': ['1645207706897113089']},
#   {'id': '1645207704544198659',
#    'lang': 'qme',
#    'text': 'RT @JCOviedo6: $TSLA\n\nhttps://t.co/ARdMWAjkf3',
#    'created_at': '2023-04-09T23:30:57.000Z',
#    'edit_history_tweet_ids': ['1645207704544198659']},
#   {'id': '1645207694436081664',
#    'lang': 'en',
#    'text': '@AndyBxxx 4. Tesla argues that it would increase density but this is due to the size of the cell and not the actual density of the battery and if any is simply following some small increase along with the rest of the world.\n\nEVs "help", but cannot be on the same league as trains. https://t.co/0pRVe0RBU9',
#    'created_at': '2023-04-09T23:30:55.000Z',
#    'edit_history_tweet_ids': ['1645207694436081664']},
#   {'id': '1645207694364536832',
#    'lang': 'tr',
#    'text': 'RT @asenardic: gelecekteki kocam eğer yazılımcıysan Tesla işi sende ben evimize kek kalıbı aldım param bitti',
#    'created_at': '2023-04-09T23:30:55.000Z',
#    'edit_history_tweet_ids': ['1645207694364536832']},
#   {'id': '1645207677067247618',
#    'lang': 'en',
#    'text': '#Ahead Of #Elon Musk’s #Rumored #China Visit, #Report Says #Tesla Will #Set Up New #Shanghai #Plant To #Manufacture #Megapacks – Tesla (NASDAQ:TSLA) https://t.co/L3kcOWBxQ0 #musks #nasdaqtsla #visit',
#    'created_at': '2023-04-09T23:30:51.000Z',
#    'edit_history_tweet_ids': ['1645207677067247618']},
#   {'id': '1645207676043788288',
#    'lang': 'en',
#    'text': 'How come congress not goin question Elon https://t.co/H2MVmXkunj',
#    'created_at': '2023-04-09T23:30:51.000Z',
#    'edit_history_tweet_ids': ['1645207676043788288']},
#   {'id': '1645207674244698113',
#    'lang': 'en',
#    'text': "RT @GunnelsWarren: Funny. Every time Elon Musk pretends to be a self-made billionaire remember: He'd be worth $0 without $4.9 billion in co…",
#    'created_at': '2023-04-09T23:30:50.000Z',
#    'edit_history_tweet_ids': ['1645207674244698113']},
#   {'id': '1645207671744737281',
#    'lang': 'en',
#    'text': '@Tesla Wrong direction',
#    'created_at': '2023-04-09T23:30:50.000Z',
#    'edit_history_tweet_ids': ['1645207671744737281']},
#   {'id': '1645207667160530945',
#    'lang': 'en',
#    'text': "@dvorahfr @elonmusk @DavidSacks @VivekGRamaswamy @GregAbbott_TX that's a truly idiotic cartoon.  Both Biden (whom is not a 'radical left') AND elon/tesla are dramatically making progress towards reducing our dependency on and use of fossil fuels.",
#    'created_at': '2023-04-09T23:30:48.000Z',
#    'edit_history_tweet_ids': ['1645207667160530945']},
#   {'id': '1645207666913054720',
#    'lang': 'es',
#    'text': 'Mientras en 🇵🇷pendiente al mantengo.. “Muchos acuerdos han aterrizado en 🇲🇽: Tesla, la empresa electrónica taiwanesa Quanta, expansión del fabricante italiano de frenos Brembo, y un acuerdo de la alemana BMW para producir baterías y autos eléctricos. \n\nhttps://t.co/YPZOSIPiUr',
#    'created_at': '2023-04-09T23:30:48.000Z',
#    'edit_history_tweet_ids': ['1645207666913054720']},
#   {'id': '1645207664719265792',
#    'lang': 'es',
#    'text': 'RT @MDCamacaro: #DomingoDeReencuentro\nTesla construirá una fábrica de baterías Megapack en Shanghái',
#    'created_at': '2023-04-09T23:30:48.000Z',
#    'edit_history_tweet_ids': ['1645207664719265792']},
#   {'id': '1645207662248747010',
#    'lang': 'en',
#    'text': 'RT @SaycheeseDGTL: 😢 Former Tesla worker Owen Diaz was awarded $137M last year for dealing with racism on the job “The supervisor called hi…',
#    'created_at': '2023-04-09T23:30:47.000Z',
#    'edit_history_tweet_ids': ['1645207662248747010']},
#   {'id': '1645207653415796736',
#    'lang': 'en',
#    'text': '@mundanemun @blueskykites @TeslaUniverse_ @Tesla @WholeMarsBlog @Kristennetten @S4njuBajaj @teardowntitan @WestTeslarado @PauljHorton @atk0506 @WIsitlike @Amy_Sober @TeslaDiva99 @R6Alex @shortword @Nikola_Truth @1stMarsColonist @CorySteuben @MadTorque @JhonnyOnasis @MobofJoggers @InchaustiRon 🤗♥️\n\nHowever too little photos of you and me…! 😂',
#    'created_at': '2023-04-09T23:30:45.000Z',
#    'edit_history_tweet_ids': ['1645207653415796736']},
#   {'id': '1645207649061941248',
#    'lang': 'es',
#    'text': 'RT @Chavista0101: #DomingoDeReencuentro\nTesla construirá una fábrica de baterías Megapack en Shanghái',
#    'created_at': '2023-04-09T23:30:44.000Z',
#    'edit_history_tweet_ids': ['1645207649061941248']},
#   {'id': '1645207644410642432',
#    'lang': 'en',
#    'text': '@engineers_feed by faith: 2024 AD   @Tesla Sub.   already an ev\nnot too much of a stretch. and eARTh is 70% water.\nlmk?',
#    'created_at': '2023-04-09T23:30:43.000Z',
#    'edit_history_tweet_ids': ['1645207644410642432']},
#   {'id': '1645207637020250112',
#    'lang': 'qme',
#    'text': 'RT @memesus77: @tearsintherain1 @nachodelaheysus @ALi3NKAT @StarshipDock @PryZmRuleZZ @TeslaDarth @Michaeldoge420 @QuantumFekT @IamCelineMa…',
#    'created_at': '2023-04-09T23:30:41.000Z',
#    'edit_history_tweet_ids': ['1645207637020250112']},
#   {'id': '1645207636852330501',
#    'lang': 'en',
#    'text': '@gabbie_tesla Mario Bros, Mario Kart, &amp; Street Fighter',
#    'created_at': '2023-04-09T23:30:41.000Z',
#    'edit_history_tweet_ids': ['1645207636852330501']},
#   {'id': '1645207628153499648',
#    'lang': 'en',
#    'text': 'RT @DarrigoMelanie: Tesla, SpaceX and SolarCity received at least $4.9 Billion in government subsidies, and more in tax breaks.\n\nBy compari…',
#    'created_at': '2023-04-09T23:30:39.000Z',
#    'edit_history_tweet_ids': ['1645207628153499648']},
#   {'id': '1645207627117510662',
#    'lang': 'en',
#    'text': 'RT @Tslachan: $TSLA @elonmusk \n* Can We Think Of The exponential Growth Of Tesla Megapack?\n🗣️ Elon : energy storage business will grow fast…',
#    'created_at': '2023-04-09T23:30:39.000Z',
#    'edit_history_tweet_ids': ['1645207627117510662']},
#   {'id': '1645207616589529088',
#    'lang': 'en',
#    'text': 'RT @DarrigoMelanie: Tesla, SpaceX and SolarCity received at least $4.9 Billion in government subsidies, and more in tax breaks.\n\nBy compari…',
#    'created_at': '2023-04-09T23:30:36.000Z',
#    'edit_history_tweet_ids': ['1645207616589529088']},
#   {'id': '1645207612328214529',
#    'lang': 'en',
#    'text': 'RT @SawyerMerritt: BREAKING: @Tesla will build a Megapack factory in Shanghai, Chinese state media outlet Xinhua reported on Sunday.\n\nConst…',
#    'created_at': '2023-04-09T23:30:35.000Z',
#    'edit_history_tweet_ids': ['1645207612328214529']},
#   {'id': '1645207611791523840',
#    'lang': 'en',
#    'text': '#TWITTER?\n#OnTheINTERNETcreatddBy #DARPA\n#CreatedByFundingLegislation passed by #CONGRESS\n#ALGORE\n#SPACEX #GOVERNMENTFUNDED contracted SPACE BUS?\n#TESLA sold with #GOVERNMENTfunded INCENTIVE PROGRAMS. Driving on streets created and maintained by #GOVERNMENTFUNDING',
#    'created_at': '2023-04-09T23:30:35.000Z',
#    'edit_history_tweet_ids': ['1645207611791523840']},
#   {'id': '1645207610176438272',
#    'lang': 'en',
#    'text': 'RT @SaycheeseDGTL: 😢 Former Tesla worker Owen Diaz was awarded $137M last year for dealing with racism on the job “The supervisor called hi…',
#    'created_at': '2023-04-09T23:30:35.000Z',
#    'edit_history_tweet_ids': ['1645207610176438272']},
#   {'id': '1645207608851038209',
#    'lang': 'en',
#    'text': 'RT @elonmusk: Wait for it …',
#    'created_at': '2023-04-09T23:30:35.000Z',
#    'edit_history_tweet_ids': ['1645207608851038209']},
#   {'id': '1645207605986357251',
#    'lang': 'en',
#    'text': 'RT @DarrigoMelanie: Tesla, SpaceX and SolarCity received at least $4.9 Billion in government subsidies, and more in tax breaks.\n\nBy compari…',
#    'created_at': '2023-04-09T23:30:34.000Z',
#    'edit_history_tweet_ids': ['1645207605986357251']},
#   {'id': '1645207600449966080',
#    'lang': 'en',
#    'text': "RT @0ccultbot: Many of Nikola Tesla's most important inventions have NEVER been released to the public and never will be.",
#    'created_at': '2023-04-09T23:30:33.000Z',
#    'edit_history_tweet_ids': ['1645207600449966080']},
#   {'id': '1645207598185218048',
#    'lang': 'en',
#    'text': 'RT @LuisT5553: Tesla malfunctions on highway, stops, starts smoking, and explodes roughly 16 times. EVs are bombs waiting to go off. 😳😳😳😳😳😲…',
#    'created_at': '2023-04-09T23:30:32.000Z',
#    'edit_history_tweet_ids': ['1645207598185218048']},
#   {'id': '1645207595878055936',
#    'lang': 'es',
#    'text': 'RT @pigdemont_: Si tienes un Tesla y te da un calentón con la parienta, mejor te es esperas a llegar a casa. https://t.co/N8bVepxxGa',
#    'created_at': '2023-04-09T23:30:31.000Z',
#    'edit_history_tweet_ids': ['1645207595878055936']},
#   {'id': '1645207585476231170',
#    'lang': 'en',
#    'text': 'RT @SaycheeseDGTL: 😢 Former Tesla worker Owen Diaz was awarded $137M last year for dealing with racism on the job “The supervisor called hi…',
#    'created_at': '2023-04-09T23:30:29.000Z',
#    'edit_history_tweet_ids': ['1645207585476231170']},
#   {'id': '1645207581428686849',
#    'lang': 'en',
#    'text': 'RT @Tesla: Our next Megafactory will be in Shanghai 🇨🇳—capable of producing 10k Megapacks per year https://t.co/KlVGq5gYOg',
#    'created_at': '2023-04-09T23:30:28.000Z',
#    'edit_history_tweet_ids': ['1645207581428686849']},
#   {'id': '1645207576064282624',
#    'lang': 'en',
#    'text': 'RT @EvaFoxU: Tesla has installed 45,000 Supercharger stalls worldwide, greatly accelerating the pace of rollout in recent months ⚡️⚡️⚡️ Cha…',
#    'created_at': '2023-04-09T23:30:27.000Z',
#    'edit_history_tweet_ids': ['1645207576064282624']},
#   {'id': '1645207568938328064',
#    'lang': 'ja',
#    'text': 'RT @16kthir0GRXgNqn: テスラ 上海にメガパックエネルギー貯蔵製品の工場を建設する予定https://t.co/m89uZ72qbh\n\n #テスラ\u3000#テスラ株 #イーロンマスク #elonmusk #cybertruck\u3000#chatgpt  #openai…',
#    'created_at': '2023-04-09T23:30:25.000Z',
#    'edit_history_tweet_ids': ['1645207568938328064']},
#   {'id': '1645207564647563265',
#    'lang': 'en',
#    'text': "Elon Musk has produced a techno track about NFTs he's selling as an NFT.\nhttps://t.co/2CWBDA1qA7",
#    'created_at': '2023-04-09T23:30:24.000Z',
#    'edit_history_tweet_ids': ['1645207564647563265']},
#   {'id': '1645207564433645568',
#    'lang': 'en',
#    'text': 'RT @DimaZeniuk: Tesla Cybertruck spotted in Fremont ⚡\U0001fa76\n\n📸: @teslaownersSV \n@Tesla @elonmusk https://t.co/GrVnOIUU9r',
#    'created_at': '2023-04-09T23:30:24.000Z',
#    'edit_history_tweet_ids': ['1645207564433645568']},
#   {'id': '1645207558901170179',
#    'lang': 'qme',
#    'text': '@tearsintherain1 @nachodelaheysus @ALi3NKAT @StarshipDock @PryZmRuleZZ @TeslaDarth @Michaeldoge420 @QuantumFekT @IamCelineMarie @TheKatsKid1 @lottkaren54 @Lionelclone1 @safferpsyche @SpadersNFTs @AndreMillaire @Rajtwittz @DogeAccept @musicphantom69 @jewel_gardener @d1dave123 @dawnheartLRPS @sofakingdoge2nd @kym_head @YeshuaisSavior @PiaPanda96 @PleiadesPlZ @YadiraRussell9 @YOUniverse999 @MaximoBanksy @bugaloo_2 @13dogecoin @boozelee86 @h_artsNcrafts @MarshaW15161057 @codehurtsbrain @elonmusk @Tesla @Tesla_Megapack @Grimezsz @dogecoin @Nike @SpaceCrystalZ @historydefined @HistoryInPics @NelsonMandela @YourHomeMars @SpaceX 😋',
#    'created_at': '2023-04-09T23:30:23.000Z',
#    'edit_history_tweet_ids': ['1645207558901170179']},
#   {'id': '1645207556078419968',
#    'lang': 'en',
#    'text': '@Zclove2bme @Tesla What did I miss?',
#    'created_at': '2023-04-09T23:30:22.000Z',
#    'edit_history_tweet_ids': ['1645207556078419968']},
#   {'id': '1645207554388099073',
#    'lang': 'es',
#    'text': '💰 Tesla impulsa inversión en China y anuncia nueva fábrica de baterías a gran escala en Shanghái https://t.co/paYRWUKN7j https://t.co/sMe551Nw19',
#    'created_at': '2023-04-09T23:30:22.000Z',
#    'edit_history_tweet_ids': ['1645207554388099073']},
#   {'id': '1645207551749890048',
#    'lang': 'en',
#    'text': 'RT @patel_patriot: Did you know China’s CATL, the worlds largest producer of lithium batteries, has a deal to provide batteries to Tesla?…',
#    'created_at': '2023-04-09T23:30:21.000Z',
#    'edit_history_tweet_ids': ['1645207551749890048']},
#   {'id': '1645207551624073217',
#    'lang': 'en',
#    'text': 'RT @DarrigoMelanie: Tesla, SpaceX and SolarCity received at least $4.9 Billion in government subsidies, and more in tax breaks.\n\nBy compari…',
#    'created_at': '2023-04-09T23:30:21.000Z',
#    'edit_history_tweet_ids': ['1645207551624073217']},
#   {'id': '1645207544376205312',
#    'lang': 'es',
#    'withheld': {'copyright': False,
#     'country_codes': ['AT',
#      'BE',
#      'BG',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'EE',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'HR',
#      'HU',
#      'IE',
#      'IT',
#      'LT',
#      'LU',
#      'LV',
#      'MT',
#      'NL',
#      'PL',
#      'PT',
#      'RO',
#      'SE',
#      'SI',
#      'SK']},
#    'text': 'RT @ActualidadRT: Tesla construirá una fábrica de baterías Megapack en Shanghái\n\nSe espera que produzca inicialmente 10.000 unidades por añ…',
#    'created_at': '2023-04-09T23:30:19.000Z',
#    'edit_history_tweet_ids': ['1645207544376205312']},
#   {'id': '1645207543239835648',
#    'lang': 'ja',
#    'text': 'テスラ 上海にメガパックエネルギー貯蔵製品の工場を建設する予定https://t.co/m89uZ72qbh\n\n #テスラ\u3000#テスラ株 #イーロンマスク #elonmusk #cybertruck\u3000#chatgpt  #openai  #microsoft  #google #TSLA #Tesla #Model3 #ModelY #ModelS #ModelX #ロボタクシー  #投資 #資産運用 #EV #AI #暗号資産',
#    'created_at': '2023-04-09T23:30:19.000Z',
#    'edit_history_tweet_ids': ['1645207543239835648']},
#   {'id': '1645207541062725635',
#    'lang': 'en',
#    'text': 'RT @elonmusk: Tesla opening Megapack factory in Shanghai to supplement output of Megapack factory in California',
#    'created_at': '2023-04-09T23:30:18.000Z',
#    'edit_history_tweet_ids': ['1645207541062725635']},
#   {'id': '1645207531680088065',
#    'lang': 'en',
#    'text': 'RT @elonmusk: @DavidSacks @VivekGRamaswamy @GregAbbott_TX Yeah, wrong on many levels. Tesla is increasing production rapidly in Texas, Cali…',
#    'created_at': '2023-04-09T23:30:16.000Z',
#    'edit_history_tweet_ids': ['1645207531680088065']},
#   {'id': '1645207527821307904',
#    'lang': 'en',
#    'text': 'RT @teslacarsonly: THE DOPEST PHOTO OF TESLA SEMI TRUCK DELIVERING TESLAS.⚡ https://t.co/lCFOLVN7jk',
#    'created_at': '2023-04-09T23:30:15.000Z',
#    'edit_history_tweet_ids': ['1645207527821307904']},
#   {'id': '1645207513745301504',
#    'lang': 'en',
#    'text': 'RT @garyblack00: Once ramped, this will effectively double $TSLA megapack capacity to 20K megapacks/year. That could be worth +$50B/yr new…',
#    'created_at': '2023-04-09T23:30:12.000Z',
#    'edit_history_tweet_ids': ['1645207513745301504']},
#   {'id': '1645207511014821889',
#    'lang': 'en',
#    'text': '@EZebroni @Tesla Ahh makes sense',
#    'created_at': '2023-04-09T23:30:11.000Z',
#    'edit_history_tweet_ids': ['1645207511014821889']},
#   {'id': '1645207503007883264',
#    'lang': 'en',
#    'text': 'Tesla Inc. is planning to install iron-based batteries that are not only cheaper, but less of a fire hazard, in a version of an affordable electric vehicle and a semi heavy electric truck, according to reports.  https://t.co/DUvOH1kDHQ',
#    'created_at': '2023-04-09T23:30:09.000Z',
#    'edit_history_tweet_ids': ['1645207503007883264']},
#   {'id': '1645207499576860674',
#    'lang': 'en',
#    'text': 'The factory will initially produce 10,000 Megapack units a year, equal to around 40 gigawatt hours of #energy storage, to be sold globally. \n\n#Tesla #ElonMusk #BusinessNews #China #Shanghai  https://t.co/CAkVTRB9Qw',
#    'created_at': '2023-04-09T23:30:09.000Z',
#    'edit_history_tweet_ids': ['1645207499576860674']},
#   {'id': '1645207497379119110',
#    'lang': 'en',
#    'text': 'RT @spieckerman: Great move for U.S. national security &amp; economy. Environmental benefits a crucial bonus.\n\nHigh U.S. gas consumption props-…',
#    'created_at': '2023-04-09T23:30:08.000Z',
#    'edit_history_tweet_ids': ['1645207497379119110']},
#   {'id': '1645207494862729216',
#    'lang': 'en',
#    'text': 'RT @TeslaSynopsis: Happy Easter 🐰. Let the red Tesla bus take you for a ride! https://t.co/EWC7WggvsN',
#    'created_at': '2023-04-09T23:30:07.000Z',
#    'edit_history_tweet_ids': ['1645207494862729216']},
#   {'id': '1645207489556692996',
#    'lang': 'en',
#    'text': 'Tesla Accused of Breaching Customer Privacy With Secretly Shared Camera Footage \n https://t.co/xV5IDhh58B',
#    'created_at': '2023-04-09T23:30:06.000Z',
#    'edit_history_tweet_ids': ['1645207489556692996']},
#   {'id': '1645207485421158400',
#    'lang': 'en',
#    'text': "Elon Musk reveals plans for a new factory making Megapacks on Shanghai visit, while Apple mulls 'decoupling' from China https://t.co/kkIL13Ki97 #engineering #technology",
#    'created_at': '2023-04-09T23:30:05.000Z',
#    'edit_history_tweet_ids': ['1645207485421158400']},
#   {'id': '1645207483043008512',
#    'lang': 'et',
#    'text': 'RT @Lucian240747241: Tesla head\n#fingering #pyt #ebony #blowjob #deepthroat #sloppy #slurping #gawkgawk #snowbunny #bimbo #latina #throat #…',
#    'created_at': '2023-04-09T23:30:05.000Z',
#    'edit_history_tweet_ids': ['1645207483043008512']},
#   {'id': '1645207458204332034',
#    'lang': 'fr',
#    'text': 'RT @Angel_Gender: JOYEUX ANNIVERSAIRE TESLA\n#affiche 😜🤧🥳❤️🐱 https://t.co/u8w01Q1biS',
#    'created_at': '2023-04-09T23:29:59.000Z',
#    'edit_history_tweet_ids': ['1645207458204332034']},
#   {'id': '1645207453976657921',
#    'lang': 'en',
#    'text': '@abhinav_kumarrr @elonmusk Well, Elon tried once. Very high tax on EVs in India, as much as 100% (15% in china) so a 50 L worth of a Tesla car would be sold at 1 cr here. Duties tax is also very high here in India compared to China and other countries🤷🏼\u200d♂️',
#    'created_at': '2023-04-09T23:29:58.000Z',
#    'edit_history_tweet_ids': ['1645207453976657921']},
#   {'id': '1645207447135719424',
#    'lang': 'en',
#    'text': '@elonmusk @TimSweeneyEpic Will recognising different English accents come to @tesla soon?',
#    'created_at': '2023-04-09T23:29:56.000Z',
#    'edit_history_tweet_ids': ['1645207447135719424']},
#   {'id': '1645207439925723136',
#    'lang': 'en',
#    'text': '@Tesla I avoid buying anything made in Communist China.',
#    'created_at': '2023-04-09T23:29:54.000Z',
#    'edit_history_tweet_ids': ['1645207439925723136']},
#   {'id': '1645207436821774338',
#    'lang': 'en',
#    'text': 'RT @TheTaijiNews: @ZoeSchiffer Sounds like a familiar Elon business practice. https://t.co/zdI3XSUKdV',
#    'created_at': '2023-04-09T23:29:54.000Z',
#    'edit_history_tweet_ids': ['1645207436821774338']},
#   {'id': '1645207423282552833',
#    'lang': 'en',
#    'text': "@MooseHornRiver @EDUESPANA @Tesla I don't feel like explaining to Musk. He can easily explain himself. However, if liberals really care that much about China's disrespect for human life, then stop speaking against the CCP on camera while doing business under the table with them! It’s common sense.",
#    'created_at': '2023-04-09T23:29:50.000Z',
#    'edit_history_tweet_ids': ['1645207423282552833']},
#   {'id': '1645207420354920451',
#    'lang': 'en',
#    'text': 'RT @peterdog15: Giga Texas is cranking out &amp; shipping more Model Ys than ever with 50 per hour based on my time here today! Berlin beware!!…',
#    'created_at': '2023-04-09T23:29:50.000Z',
#    'edit_history_tweet_ids': ['1645207420354920451']},
#   {'id': '1645207420132634624',
#    'lang': 'es',
#    'text': '@renacova Dicen los hijos de tesla qué el único que los puede tratar como pendejos es Samuel García',
#    'created_at': '2023-04-09T23:29:50.000Z',
#    'edit_history_tweet_ids': ['1645207420132634624']},
#   {'id': '1645207415472680964',
#    'lang': 'es',
#    'text': 'Tesla construirá una nueva fábrica de baterías en China #Expansioncom https://t.co/aayHX4FZHP',
#    'created_at': '2023-04-09T23:29:48.000Z',
#    'edit_history_tweet_ids': ['1645207415472680964']},
#   {'id': '1645207413081948166',
#    'lang': 'en',
#    'text': 'RT @CNN: The factory will be able to produce 10,000 Megapacks — very large batteries used to store utility-scale amounts of electricity — p…',
#    'created_at': '2023-04-09T23:29:48.000Z',
#    'edit_history_tweet_ids': ['1645207413081948166']},
#   {'id': '1645207409428766722',
#    'lang': 'qme',
#    'text': '@nachodelaheysus @tearsintherain1 @ALi3NKAT @StarshipDock @PryZmRuleZZ @TeslaDarth @Michaeldoge420 @QuantumFekT @IamCelineMarie @TheKatsKid1 @lottkaren54 @Lionelclone1 @safferpsyche @SpadersNFTs @AndreMillaire @Rajtwittz @DogeAccept @musicphantom69 @jewel_gardener @d1dave123 @dawnheartLRPS @sofakingdoge2nd @kym_head @YeshuaisSavior @PiaPanda96 @PleiadesPlZ @YadiraRussell9 @YOUniverse999 @MaximoBanksy @bugaloo_2 @13dogecoin @boozelee86 @h_artsNcrafts @MarshaW15161057 @codehurtsbrain @elonmusk @Tesla @Tesla_Megapack @Grimezsz @dogecoin @Nike @SpaceCrystalZ @historydefined @HistoryInPics @NelsonMandela @YourHomeMars @SpaceX 🔥🔥🔥',
#    'created_at': '2023-04-09T23:29:47.000Z',
#    'edit_history_tweet_ids': ['1645207409428766722']},
#   {'id': '1645207398943014912',
#    'lang': 'en',
#    'withheld': {'copyright': False, 'country_codes': ['ID']},
#    'text': 'RT @ValaAfshar: @elonmusk If you want to find the secrets of the universe, think in terms of energy, frequency and vibration.\n\n—Nikola Tesl…',
#    'created_at': '2023-04-09T23:29:45.000Z',
#    'edit_history_tweet_ids': ['1645207398943014912']},
#   {'id': '1645207397324009475',
#    'lang': 'en',
#    'text': 'RT @tearsintherain1: @nachodelaheysus @ALi3NKAT @StarshipDock @PryZmRuleZZ @TeslaDarth @Michaeldoge420 @QuantumFekT @IamCelineMarie @TheKat…',
#    'created_at': '2023-04-09T23:29:44.000Z',
#    'edit_history_tweet_ids': ['1645207397324009475']},
#   {'id': '1645207394467868673',
#    'lang': 'en',
#    'text': '@AHCapMgmt @Jones1CDSR @Tesla More than offset. One is a strategy that bears have overplayed. This is development in the right direction. I m more of a longer term investor. I see further into the future. The bears r just making noises. Price cuts spur adoption.',
#    'created_at': '2023-04-09T23:29:43.000Z',
#    'edit_history_tweet_ids': ['1645207394467868673']},
#   {'id': '1645207368953737218',
#    'lang': 'en',
#    'text': '@nachodelaheysus @ALi3NKAT @StarshipDock @PryZmRuleZZ @TeslaDarth @Michaeldoge420 @QuantumFekT @IamCelineMarie @TheKatsKid1 @lottkaren54 @Lionelclone1 @safferpsyche @memesus77 @SpadersNFTs @AndreMillaire @Rajtwittz @DogeAccept @musicphantom69 @jewel_gardener @d1dave123 @dawnheartLRPS @sofakingdoge2nd @kym_head @YeshuaisSavior @PiaPanda96 @PleiadesPlZ @YadiraRussell9 @YOUniverse999 @MaximoBanksy @bugaloo_2 @13dogecoin @boozelee86 @h_artsNcrafts @MarshaW15161057 @codehurtsbrain @elonmusk @Tesla @Tesla_Megapack @Grimezsz @dogecoin @Nike @SpaceCrystalZ @historydefined @HistoryInPics @NelsonMandela @YourHomeMars @SpaceX I just come here for the free food 🥘',
#    'created_at': '2023-04-09T23:29:37.000Z',
#    'edit_history_tweet_ids': ['1645207368953737218']},
#   {'id': '1645207361349361666',
#    'lang': 'en',
#    'text': '@Rebecca61017020 Reach out to Big Tesla for direct access to free signals, Trade Analysis and mentorship programs\n✅\n\nhttps://t.co/ixpv0wQ7AS',
#    'created_at': '2023-04-09T23:29:36.000Z',
#    'edit_history_tweet_ids': ['1645207361349361666']},
#   {'id': '1645207361118674944',
#    'lang': 'en',
#    'text': 'Wow, Tesla faces class action privacy lawsuit, following startling revelations https://t.co/I3h9DFdGOi',
#    'created_at': '2023-04-09T23:29:36.000Z',
#    'edit_history_tweet_ids': ['1645207361118674944']},
#   {'id': '1645207354969931777',
#    'lang': 'en',
#    'text': 'If Elon Musk is from South Africa, why is Tesla building a huge battery factory in China? Why not locate such project in an African country where the labor is cheap, and will create job for Africans?',
#    'created_at': '2023-04-09T23:29:34.000Z',
#    'edit_history_tweet_ids': ['1645207354969931777']},
#   {'id': '1645207349533999104',
#    'lang': 'en',
#    'text': '@elonmusk Tesla is not Alian car ? 🤔',
#    'created_at': '2023-04-09T23:29:33.000Z',
#    'edit_history_tweet_ids': ['1645207349533999104']},
#   {'id': '1645207349110669313',
#    'lang': 'en',
#    'text': 'RT @maskofbun: the fact that this concept art was supposed to be vash 1) shows how much he resembles tesla and aligns with the theory that…',
#    'created_at': '2023-04-09T23:29:33.000Z',
#    'edit_history_tweet_ids': ['1645207349110669313']},
#   {'id': '1645207348548452354',
#    'lang': 'en',
#    'text': 'RT @nytimes: Tesla will build a factory in Shanghai to manufacture its large-scale energy-storage batteries known as the Megapack, the Chin…',
#    'created_at': '2023-04-09T23:29:33.000Z',
#    'edit_history_tweet_ids': ['1645207348548452354']},
#   {'id': '1645207341858471942',
#    'lang': 'en',
#    'text': '@AryanPigkaw Do Einstein and Tesla have competing claims?',
#    'created_at': '2023-04-09T23:29:31.000Z',
#    'edit_history_tweet_ids': ['1645207341858471942']},
#   {'id': '1645207339840987136',
#    'lang': 'en',
#    'text': 'RT @ZainulA36741500: @elonmusk @SawyerMerritt @Tesla Alerts crypto trader! They predicted that Bitcoin could fall to $5,000 levels in 2023.…',
#    'created_at': '2023-04-09T23:29:30.000Z',
#    'edit_history_tweet_ids': ['1645207339840987136']},
#   {'id': '1645207339740418050',
#    'lang': 'en',
#    'text': 'RT @6abc: A Tesla owner filed a complaint accusing the company of allegedly violating California privacy laws, among other claims.  https:/…',
#    'created_at': '2023-04-09T23:29:30.000Z',
#    'edit_history_tweet_ids': ['1645207339740418050']},
#   {'id': '1645207336602988544',
#    'lang': 'en',
#    'text': 'RT @Vespa_sa_gedli: Tesla -1.12%, Apple -0.33%, AI -26.34%, AMC -23.48%, Dow Jones Industrial -198 pts, Bitcoin 28,226 https://t.co/YM7CtC9…',
#    'created_at': '2023-04-09T23:29:30.000Z',
#    'edit_history_tweet_ids': ['1645207336602988544']},
#   {'id': '1645207335005036544',
#    'lang': 'en',
#    'text': '@VivekGRamaswamy @elonmusk Megapack has nothing to do with EVs. It’s grid-scale battery storage. Also EVs for American consumers are made in America in Tesla’s factories in California, Nevada and Texas',
#    'created_at': '2023-04-09T23:29:29.000Z',
#    'edit_history_tweet_ids': ['1645207335005036544']},
#   {'id': '1645207331242639363',
#    'lang': 'en',
#    'text': 'RT @SaycheeseDGTL: 😢 Former Tesla worker Owen Diaz was awarded $137M last year for dealing with racism on the job “The supervisor called hi…',
#    'created_at': '2023-04-09T23:29:28.000Z',
#    'edit_history_tweet_ids': ['1645207331242639363']},
#   {'id': '1645207330466803714',
#    'lang': 'en',
#    'text': 'RT @IEEESpectrum: Developing cells for drones and air taxis is one way to achieve lightweight battery breakthroughs. This company has doubl…',
#    'created_at': '2023-04-09T23:29:28.000Z',
#    'edit_history_tweet_ids': ['1645207330466803714']},
#   {'id': '1645207324993417216',
#    'lang': 'en',
#    'text': "RT @MuskUniversity: “Focus on signal over noise. A lot of companies get confused, they spend money on things that don't actually make the p…",
#    'created_at': '2023-04-09T23:29:27.000Z',
#    'edit_history_tweet_ids': ['1645207324993417216']},
#   {'id': '1645207311894339585',
#    'lang': 'en',
#    'text': 'RT @DillonLoomis22: A lot of chatter about $TSLA growth rates slowing, demand falling, advertising needs etc. \n\nNot to oversimplify, but ca…',
#    'created_at': '2023-04-09T23:29:24.000Z',
#    'edit_history_tweet_ids': ['1645207311894339585']},
#   {'id': '1645207308513812480',
#    'lang': 'en',
#    'text': 'RT @factchecking18: "We’ll also go after the Wall St short-sellers ... "\n\nSaid the $DOGE-pump-master 🤣\n\n#Musk \n#Tesla \n#Bitcoin https://t.c…',
#    'created_at': '2023-04-09T23:29:23.000Z',
#    'edit_history_tweet_ids': ['1645207308513812480']},
#   {'id': '1645207305708015620',
#    'lang': 'en',
#    'text': '@MeniTsirbas @CornelyTristan @LucidMotors @Tesla not devoted to any company. $TSLA is my biggest investment followed by $LCID (distant 2nd) &amp; RIVN. love good engineering and making money. Just want to end this by saying, in 2023, a company with a stunning EV will make it. 86% auto market share still there for EVs to capture. GD',
#    'created_at': '2023-04-09T23:29:22.000Z',
#    'edit_history_tweet_ids': ['1645207305708015620']}],
#  'meta': {'newest_id': '1645207791890513920',
#   'oldest_id': '1645207305708015620',
#   'result_count': 100,
#   'next_token': 'b26v89c19zqg8o3fqkd0rv6ra1xqnha3sda67dqr6zgjh'}}

# %% [markdown]
# Adding multiple parameters and using complex queries can make our address string method cumbersome to work with. It is better practice to ad our parameters inside the `params` argument of our request.

# %%
params = {
    'query' : 'Tesla',
    'tweet.fields': 'created_at,lang',
    'max_results':'100'
}
response = requests.get('https://api.twitter.com/2/tweets/search/recent', 
                        headers = headers, params=params)
response.json()
# Out:
# {'data': [{'edit_history_tweet_ids': ['1645207791890513920'],
#    'id': '1645207791890513920',
#    'lang': 'en',
#    'created_at': '2023-04-09T23:31:18.000Z',
#    'text': "@memesus77 @tearsintherain1 @ALi3NKAT @StarshipDock @PryZmRuleZZ @TeslaDarth @Michaeldoge420 @QuantumFekT @IamCelineMarie @TheKatsKid1 @lottkaren54 @Lionelclone1 @safferpsyche @SpadersNFTs @AndreMillaire @Rajtwittz @DogeAccept @musicphantom69 @jewel_gardener @d1dave123 @dawnheartLRPS @sofakingdoge2nd @kym_head @YeshuaisSavior @PiaPanda96 @PleiadesPlZ @YadiraRussell9 @YOUniverse999 @MaximoBanksy @bugaloo_2 @13dogecoin @boozelee86 @h_artsNcrafts @MarshaW15161057 @codehurtsbrain @elonmusk @Tesla @Tesla_Megapack @Grimezsz @dogecoin @Nike @SpaceCrystalZ @historydefined @HistoryInPics @NelsonMandela @YourHomeMars @SpaceX Is everyone scheduled and excited for bear hug Thursday it's coming up ya know....\n\nSigh 😕 https://t.co/btJxNITJuH"},
#   {'edit_history_tweet_ids': ['1645207779123118080'],
#    'id': '1645207779123118080',
#    'lang': 'qme',
#    'created_at': '2023-04-09T23:31:15.000Z',
#    'text': '@SawyerMerritt @Tesla https://t.co/r0f31PhSxb'},
#   {'edit_history_tweet_ids': ['1645207775113523203'],
#    'id': '1645207775113523203',
#    'lang': 'qme',
#    'created_at': '2023-04-09T23:31:14.000Z',
#    'text': '@Nikola_Truth @blueskykites @TeslaUniverse_ @Tesla @WholeMarsBlog @Kristennetten @S4njuBajaj @teardowntitan @WestTeslarado @PauljHorton @atk0506 @WIsitlike @mundanemun @Amy_Sober @TeslaDiva99 @R6Alex @shortword @1stMarsColonist @CorySteuben @MadTorque @JhonnyOnasis @MobofJoggers @InchaustiRon 🥳🚀♥️'},
#   {'edit_history_tweet_ids': ['1645207772248653824'],
#    'id': '1645207772248653824',
#    'lang': 'qam',
#    'created_at': '2023-04-09T23:31:14.000Z',
#    'text': '@Tesla @elonmusk @NissanElectric @ford @Rivian @ENERGY @environmentca @cbc @CTVNews @JustinTrudeau @JoeBiden https://t.co/78LuPzk5k8'},
#   {'edit_history_tweet_ids': ['1645207760634626048'],
#    'id': '1645207760634626048',
#    'lang': 'und',
#    'created_at': '2023-04-09T23:31:11.000Z',
#    'text': '@memesus77 @nachodelaheysus @ALi3NKAT @StarshipDock @PryZmRuleZZ @TeslaDarth @Michaeldoge420 @QuantumFekT @IamCelineMarie @TheKatsKid1 @lottkaren54 @Lionelclone1 @safferpsyche @SpadersNFTs @AndreMillaire @Rajtwittz @DogeAccept @musicphantom69 @jewel_gardener @d1dave123 @dawnheartLRPS @sofakingdoge2nd @kym_head @YeshuaisSavior @PiaPanda96 @PleiadesPlZ @YadiraRussell9 @YOUniverse999 @MaximoBanksy @bugaloo_2 @13dogecoin @boozelee86 @h_artsNcrafts @MarshaW15161057 @codehurtsbrain @elonmusk @Tesla @Tesla_Megapack @Grimezsz @dogecoin @Nike @SpaceCrystalZ @historydefined @HistoryInPics @NelsonMandela @YourHomeMars @SpaceX Lol 😝'},
#   {'edit_history_tweet_ids': ['1645207751646392320'],
#    'id': '1645207751646392320',
#    'lang': 'en',
#    'created_at': '2023-04-09T23:31:09.000Z',
#    'text': 'RT @elonmusk: @DavidSacks @VivekGRamaswamy @GregAbbott_TX Yeah, wrong on many levels. Tesla is increasing production rapidly in Texas, Cali…'},
#   {'edit_history_tweet_ids': ['1645207748722798592'],
#    'id': '1645207748722798592',
#    'lang': 'en',
#    'created_at': '2023-04-09T23:31:08.000Z',
#    'text': '@hyteckit @farzyness The big one with these Tesla cars that everybody seems to forget is to check the blinker fluid.'},
#   {'edit_history_tweet_ids': ['1645207748362084356'],
#    'id': '1645207748362084356',
#    'lang': 'en',
#    'created_at': '2023-04-09T23:31:08.000Z',
#    'text': '@indigenoussista He originally brought the fight to Tesla on his own.  Then a Blk female HR filed her complaint after his lawyers case was set for settlement before he won in court.  She was in HR and did nothing the entire time but ignore the racist actions of the management team.'},
#   {'edit_history_tweet_ids': ['1645207743375220736'],
#    'id': '1645207743375220736',
#    'lang': 'zh',
#    'created_at': '2023-04-09T23:31:07.000Z',
#    'text': 'Tesla 人形機器人\n\nhttps://t.co/984T8usZB8'},
#   {'edit_history_tweet_ids': ['1645207738446651392'],
#    'id': '1645207738446651392',
#    'lang': 'en',
#    'created_at': '2023-04-09T23:31:05.000Z',
#    'text': 'RT @SaycheeseDGTL: 😢 Former Tesla worker Owen Diaz was awarded $137M last year for dealing with racism on the job “The supervisor called hi…'},
#   {'edit_history_tweet_ids': ['1645207728627875843'],
#    'id': '1645207728627875843',
#    'lang': 'en',
#    'created_at': '2023-04-09T23:31:03.000Z',
#    'text': '@msaunby @KaramMacro @ParikPatelCFA @RobinWigg Yeah Tesla just seems like they are dogshit and plummeting every day. Get off Twitter @elonmusk  😂'},
#   {'edit_history_tweet_ids': ['1645207725368803330'],
#    'id': '1645207725368803330',
#    'lang': 'en',
#    'created_at': '2023-04-09T23:31:02.000Z',
#    'text': '@elonmusk @WallStreetSilv will Tesla have a "government funded car company" added to it\'s twitter account?'},
#   {'edit_history_tweet_ids': ['1645207720478294023'],
#    'id': '1645207720478294023',
#    'lang': 'en',
#    'created_at': '2023-04-09T23:31:01.000Z',
#    'text': '@wieslawawy @HankMeninga @Tesla @elonmusk I only buy clothes made in South Asia because they allow child labor. I think children make better clothes'},
#   {'edit_history_tweet_ids': ['1645207710055407619'],
#    'id': '1645207710055407619',
#    'lang': 'en',
#    'created_at': '2023-04-09T23:30:59.000Z',
#    'text': '@teslamarge @DimaZeniuk @teslaownersSV @Tesla @elonmusk @TeslaNY @klwtts @WholeMarsBlog @DriveTeslaca @BrandonTSLA Ya, wheels can be changed just get me that truck asap.'},
#   {'edit_history_tweet_ids': ['1645207707304034315'],
#    'id': '1645207707304034315',
#    'lang': 'es',
#    'created_at': '2023-04-09T23:30:58.000Z',
#    'text': 'RT @TeslaSynopsis: Tesla autopark\nhttps://t.co/B2s60FGWFu'},
#   {'edit_history_tweet_ids': ['1645207706897113089'],
#    'id': '1645207706897113089',
#    'lang': 'en',
#    'created_at': '2023-04-09T23:30:58.000Z',
#    'text': 'RT @EvaFoxU: Tesla has installed 45,000 Supercharger stalls worldwide, greatly accelerating the pace of rollout in recent months ⚡️⚡️⚡️ Cha…'},
#   {'edit_history_tweet_ids': ['1645207704544198659'],
#    'id': '1645207704544198659',
#    'lang': 'qme',
#    'created_at': '2023-04-09T23:30:57.000Z',
#    'text': 'RT @JCOviedo6: $TSLA\n\nhttps://t.co/ARdMWAjkf3'},
#   {'edit_history_tweet_ids': ['1645207694436081664'],
#    'id': '1645207694436081664',
#    'lang': 'en',
#    'created_at': '2023-04-09T23:30:55.000Z',
#    'text': '@AndyBxxx 4. Tesla argues that it would increase density but this is due to the size of the cell and not the actual density of the battery and if any is simply following some small increase along with the rest of the world.\n\nEVs "help", but cannot be on the same league as trains. https://t.co/0pRVe0RBU9'},
#   {'edit_history_tweet_ids': ['1645207694364536832'],
#    'id': '1645207694364536832',
#    'lang': 'tr',
#    'created_at': '2023-04-09T23:30:55.000Z',
#    'text': 'RT @asenardic: gelecekteki kocam eğer yazılımcıysan Tesla işi sende ben evimize kek kalıbı aldım param bitti'},
#   {'edit_history_tweet_ids': ['1645207677067247618'],
#    'id': '1645207677067247618',
#    'lang': 'en',
#    'created_at': '2023-04-09T23:30:51.000Z',
#    'text': '#Ahead Of #Elon Musk’s #Rumored #China Visit, #Report Says #Tesla Will #Set Up New #Shanghai #Plant To #Manufacture #Megapacks – Tesla (NASDAQ:TSLA) https://t.co/L3kcOWBxQ0 #musks #nasdaqtsla #visit'},
#   {'edit_history_tweet_ids': ['1645207676043788288'],
#    'id': '1645207676043788288',
#    'lang': 'en',
#    'created_at': '2023-04-09T23:30:51.000Z',
#    'text': 'How come congress not goin question Elon https://t.co/H2MVmXkunj'},
#   {'edit_history_tweet_ids': ['1645207674244698113'],
#    'id': '1645207674244698113',
#    'lang': 'en',
#    'created_at': '2023-04-09T23:30:50.000Z',
#    'text': "RT @GunnelsWarren: Funny. Every time Elon Musk pretends to be a self-made billionaire remember: He'd be worth $0 without $4.9 billion in co…"},
#   {'edit_history_tweet_ids': ['1645207671744737281'],
#    'id': '1645207671744737281',
#    'lang': 'en',
#    'created_at': '2023-04-09T23:30:50.000Z',
#    'text': '@Tesla Wrong direction'},
#   {'edit_history_tweet_ids': ['1645207667160530945'],
#    'id': '1645207667160530945',
#    'lang': 'en',
#    'created_at': '2023-04-09T23:30:48.000Z',
#    'text': "@dvorahfr @elonmusk @DavidSacks @VivekGRamaswamy @GregAbbott_TX that's a truly idiotic cartoon.  Both Biden (whom is not a 'radical left') AND elon/tesla are dramatically making progress towards reducing our dependency on and use of fossil fuels."},
#   {'edit_history_tweet_ids': ['1645207666913054720'],
#    'id': '1645207666913054720',
#    'lang': 'es',
#    'created_at': '2023-04-09T23:30:48.000Z',
#    'text': 'Mientras en 🇵🇷pendiente al mantengo.. “Muchos acuerdos han aterrizado en 🇲🇽: Tesla, la empresa electrónica taiwanesa Quanta, expansión del fabricante italiano de frenos Brembo, y un acuerdo de la alemana BMW para producir baterías y autos eléctricos. \n\nhttps://t.co/YPZOSIPiUr'},
#   {'edit_history_tweet_ids': ['1645207664719265792'],
#    'id': '1645207664719265792',
#    'lang': 'es',
#    'created_at': '2023-04-09T23:30:48.000Z',
#    'text': 'RT @MDCamacaro: #DomingoDeReencuentro\nTesla construirá una fábrica de baterías Megapack en Shanghái'},
#   {'edit_history_tweet_ids': ['1645207662248747010'],
#    'id': '1645207662248747010',
#    'lang': 'en',
#    'created_at': '2023-04-09T23:30:47.000Z',
#    'text': 'RT @SaycheeseDGTL: 😢 Former Tesla worker Owen Diaz was awarded $137M last year for dealing with racism on the job “The supervisor called hi…'},
#   {'edit_history_tweet_ids': ['1645207653415796736'],
#    'id': '1645207653415796736',
#    'lang': 'en',
#    'created_at': '2023-04-09T23:30:45.000Z',
#    'text': '@mundanemun @blueskykites @TeslaUniverse_ @Tesla @WholeMarsBlog @Kristennetten @S4njuBajaj @teardowntitan @WestTeslarado @PauljHorton @atk0506 @WIsitlike @Amy_Sober @TeslaDiva99 @R6Alex @shortword @Nikola_Truth @1stMarsColonist @CorySteuben @MadTorque @JhonnyOnasis @MobofJoggers @InchaustiRon 🤗♥️\n\nHowever too little photos of you and me…! 😂'},
#   {'edit_history_tweet_ids': ['1645207649061941248'],
#    'id': '1645207649061941248',
#    'lang': 'es',
#    'created_at': '2023-04-09T23:30:44.000Z',
#    'text': 'RT @Chavista0101: #DomingoDeReencuentro\nTesla construirá una fábrica de baterías Megapack en Shanghái'},
#   {'edit_history_tweet_ids': ['1645207644410642432'],
#    'id': '1645207644410642432',
#    'lang': 'en',
#    'created_at': '2023-04-09T23:30:43.000Z',
#    'text': '@engineers_feed by faith: 2024 AD   @Tesla Sub.   already an ev\nnot too much of a stretch. and eARTh is 70% water.\nlmk?'},
#   {'edit_history_tweet_ids': ['1645207637020250112'],
#    'id': '1645207637020250112',
#    'lang': 'qme',
#    'created_at': '2023-04-09T23:30:41.000Z',
#    'text': 'RT @memesus77: @tearsintherain1 @nachodelaheysus @ALi3NKAT @StarshipDock @PryZmRuleZZ @TeslaDarth @Michaeldoge420 @QuantumFekT @IamCelineMa…'},
#   {'edit_history_tweet_ids': ['1645207636852330501'],
#    'id': '1645207636852330501',
#    'lang': 'en',
#    'created_at': '2023-04-09T23:30:41.000Z',
#    'text': '@gabbie_tesla Mario Bros, Mario Kart, &amp; Street Fighter'},
#   {'edit_history_tweet_ids': ['1645207628153499648'],
#    'id': '1645207628153499648',
#    'lang': 'en',
#    'created_at': '2023-04-09T23:30:39.000Z',
#    'text': 'RT @DarrigoMelanie: Tesla, SpaceX and SolarCity received at least $4.9 Billion in government subsidies, and more in tax breaks.\n\nBy compari…'},
#   {'edit_history_tweet_ids': ['1645207627117510662'],
#    'id': '1645207627117510662',
#    'lang': 'en',
#    'created_at': '2023-04-09T23:30:39.000Z',
#    'text': 'RT @Tslachan: $TSLA @elonmusk \n* Can We Think Of The exponential Growth Of Tesla Megapack?\n🗣️ Elon : energy storage business will grow fast…'},
#   {'edit_history_tweet_ids': ['1645207616589529088'],
#    'id': '1645207616589529088',
#    'lang': 'en',
#    'created_at': '2023-04-09T23:30:36.000Z',
#    'text': 'RT @DarrigoMelanie: Tesla, SpaceX and SolarCity received at least $4.9 Billion in government subsidies, and more in tax breaks.\n\nBy compari…'},
#   {'edit_history_tweet_ids': ['1645207612328214529'],
#    'id': '1645207612328214529',
#    'lang': 'en',
#    'created_at': '2023-04-09T23:30:35.000Z',
#    'text': 'RT @SawyerMerritt: BREAKING: @Tesla will build a Megapack factory in Shanghai, Chinese state media outlet Xinhua reported on Sunday.\n\nConst…'},
#   {'edit_history_tweet_ids': ['1645207611791523840'],
#    'id': '1645207611791523840',
#    'lang': 'en',
#    'created_at': '2023-04-09T23:30:35.000Z',
#    'text': '#TWITTER?\n#OnTheINTERNETcreatddBy #DARPA\n#CreatedByFundingLegislation passed by #CONGRESS\n#ALGORE\n#SPACEX #GOVERNMENTFUNDED contracted SPACE BUS?\n#TESLA sold with #GOVERNMENTfunded INCENTIVE PROGRAMS. Driving on streets created and maintained by #GOVERNMENTFUNDING'},
#   {'edit_history_tweet_ids': ['1645207610176438272'],
#    'id': '1645207610176438272',
#    'lang': 'en',
#    'created_at': '2023-04-09T23:30:35.000Z',
#    'text': 'RT @SaycheeseDGTL: 😢 Former Tesla worker Owen Diaz was awarded $137M last year for dealing with racism on the job “The supervisor called hi…'},
#   {'edit_history_tweet_ids': ['1645207608851038209'],
#    'id': '1645207608851038209',
#    'lang': 'en',
#    'created_at': '2023-04-09T23:30:35.000Z',
#    'text': 'RT @elonmusk: Wait for it …'},
#   {'edit_history_tweet_ids': ['1645207605986357251'],
#    'id': '1645207605986357251',
#    'lang': 'en',
#    'created_at': '2023-04-09T23:30:34.000Z',
#    'text': 'RT @DarrigoMelanie: Tesla, SpaceX and SolarCity received at least $4.9 Billion in government subsidies, and more in tax breaks.\n\nBy compari…'},
#   {'edit_history_tweet_ids': ['1645207600449966080'],
#    'id': '1645207600449966080',
#    'lang': 'en',
#    'created_at': '2023-04-09T23:30:33.000Z',
#    'text': "RT @0ccultbot: Many of Nikola Tesla's most important inventions have NEVER been released to the public and never will be."},
#   {'edit_history_tweet_ids': ['1645207598185218048'],
#    'id': '1645207598185218048',
#    'lang': 'en',
#    'created_at': '2023-04-09T23:30:32.000Z',
#    'text': 'RT @LuisT5553: Tesla malfunctions on highway, stops, starts smoking, and explodes roughly 16 times. EVs are bombs waiting to go off. 😳😳😳😳😳😲…'},
#   {'edit_history_tweet_ids': ['1645207595878055936'],
#    'id': '1645207595878055936',
#    'lang': 'es',
#    'created_at': '2023-04-09T23:30:31.000Z',
#    'text': 'RT @pigdemont_: Si tienes un Tesla y te da un calentón con la parienta, mejor te es esperas a llegar a casa. https://t.co/N8bVepxxGa'},
#   {'edit_history_tweet_ids': ['1645207585476231170'],
#    'id': '1645207585476231170',
#    'lang': 'en',
#    'created_at': '2023-04-09T23:30:29.000Z',
#    'text': 'RT @SaycheeseDGTL: 😢 Former Tesla worker Owen Diaz was awarded $137M last year for dealing with racism on the job “The supervisor called hi…'},
#   {'edit_history_tweet_ids': ['1645207581428686849'],
#    'id': '1645207581428686849',
#    'lang': 'en',
#    'created_at': '2023-04-09T23:30:28.000Z',
#    'text': 'RT @Tesla: Our next Megafactory will be in Shanghai 🇨🇳—capable of producing 10k Megapacks per year https://t.co/KlVGq5gYOg'},
#   {'edit_history_tweet_ids': ['1645207576064282624'],
#    'id': '1645207576064282624',
#    'lang': 'en',
#    'created_at': '2023-04-09T23:30:27.000Z',
#    'text': 'RT @EvaFoxU: Tesla has installed 45,000 Supercharger stalls worldwide, greatly accelerating the pace of rollout in recent months ⚡️⚡️⚡️ Cha…'},
#   {'edit_history_tweet_ids': ['1645207568938328064'],
#    'id': '1645207568938328064',
#    'lang': 'ja',
#    'created_at': '2023-04-09T23:30:25.000Z',
#    'text': 'RT @16kthir0GRXgNqn: テスラ 上海にメガパックエネルギー貯蔵製品の工場を建設する予定https://t.co/m89uZ72qbh\n\n #テスラ\u3000#テスラ株 #イーロンマスク #elonmusk #cybertruck\u3000#chatgpt  #openai…'},
#   {'edit_history_tweet_ids': ['1645207564647563265'],
#    'id': '1645207564647563265',
#    'lang': 'en',
#    'created_at': '2023-04-09T23:30:24.000Z',
#    'text': "Elon Musk has produced a techno track about NFTs he's selling as an NFT.\nhttps://t.co/2CWBDA1qA7"},
#   {'edit_history_tweet_ids': ['1645207564433645568'],
#    'id': '1645207564433645568',
#    'lang': 'en',
#    'created_at': '2023-04-09T23:30:24.000Z',
#    'text': 'RT @DimaZeniuk: Tesla Cybertruck spotted in Fremont ⚡\U0001fa76\n\n📸: @teslaownersSV \n@Tesla @elonmusk https://t.co/GrVnOIUU9r'},
#   {'edit_history_tweet_ids': ['1645207558901170179'],
#    'id': '1645207558901170179',
#    'lang': 'qme',
#    'created_at': '2023-04-09T23:30:23.000Z',
#    'text': '@tearsintherain1 @nachodelaheysus @ALi3NKAT @StarshipDock @PryZmRuleZZ @TeslaDarth @Michaeldoge420 @QuantumFekT @IamCelineMarie @TheKatsKid1 @lottkaren54 @Lionelclone1 @safferpsyche @SpadersNFTs @AndreMillaire @Rajtwittz @DogeAccept @musicphantom69 @jewel_gardener @d1dave123 @dawnheartLRPS @sofakingdoge2nd @kym_head @YeshuaisSavior @PiaPanda96 @PleiadesPlZ @YadiraRussell9 @YOUniverse999 @MaximoBanksy @bugaloo_2 @13dogecoin @boozelee86 @h_artsNcrafts @MarshaW15161057 @codehurtsbrain @elonmusk @Tesla @Tesla_Megapack @Grimezsz @dogecoin @Nike @SpaceCrystalZ @historydefined @HistoryInPics @NelsonMandela @YourHomeMars @SpaceX 😋'},
#   {'edit_history_tweet_ids': ['1645207556078419968'],
#    'id': '1645207556078419968',
#    'lang': 'en',
#    'created_at': '2023-04-09T23:30:22.000Z',
#    'text': '@Zclove2bme @Tesla What did I miss?'},
#   {'edit_history_tweet_ids': ['1645207554388099073'],
#    'id': '1645207554388099073',
#    'lang': 'es',
#    'created_at': '2023-04-09T23:30:22.000Z',
#    'text': '💰 Tesla impulsa inversión en China y anuncia nueva fábrica de baterías a gran escala en Shanghái https://t.co/paYRWUKN7j https://t.co/sMe551Nw19'},
#   {'edit_history_tweet_ids': ['1645207551749890048'],
#    'id': '1645207551749890048',
#    'lang': 'en',
#    'created_at': '2023-04-09T23:30:21.000Z',
#    'text': 'RT @patel_patriot: Did you know China’s CATL, the worlds largest producer of lithium batteries, has a deal to provide batteries to Tesla?…'},
#   {'edit_history_tweet_ids': ['1645207551624073217'],
#    'id': '1645207551624073217',
#    'lang': 'en',
#    'created_at': '2023-04-09T23:30:21.000Z',
#    'text': 'RT @DarrigoMelanie: Tesla, SpaceX and SolarCity received at least $4.9 Billion in government subsidies, and more in tax breaks.\n\nBy compari…'},
#   {'edit_history_tweet_ids': ['1645207544376205312'],
#    'id': '1645207544376205312',
#    'lang': 'es',
#    'withheld': {'copyright': False,
#     'country_codes': ['AT',
#      'BE',
#      'BG',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'EE',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'HR',
#      'HU',
#      'IE',
#      'IT',
#      'LT',
#      'LU',
#      'LV',
#      'MT',
#      'NL',
#      'PL',
#      'PT',
#      'RO',
#      'SE',
#      'SI',
#      'SK']},
#    'created_at': '2023-04-09T23:30:19.000Z',
#    'text': 'RT @ActualidadRT: Tesla construirá una fábrica de baterías Megapack en Shanghái\n\nSe espera que produzca inicialmente 10.000 unidades por añ…'},
#   {'edit_history_tweet_ids': ['1645207543239835648'],
#    'id': '1645207543239835648',
#    'lang': 'ja',
#    'created_at': '2023-04-09T23:30:19.000Z',
#    'text': 'テスラ 上海にメガパックエネルギー貯蔵製品の工場を建設する予定https://t.co/m89uZ72qbh\n\n #テスラ\u3000#テスラ株 #イーロンマスク #elonmusk #cybertruck\u3000#chatgpt  #openai  #microsoft  #google #TSLA #Tesla #Model3 #ModelY #ModelS #ModelX #ロボタクシー  #投資 #資産運用 #EV #AI #暗号資産'},
#   {'edit_history_tweet_ids': ['1645207541062725635'],
#    'id': '1645207541062725635',
#    'lang': 'en',
#    'created_at': '2023-04-09T23:30:18.000Z',
#    'text': 'RT @elonmusk: Tesla opening Megapack factory in Shanghai to supplement output of Megapack factory in California'},
#   {'edit_history_tweet_ids': ['1645207531680088065'],
#    'id': '1645207531680088065',
#    'lang': 'en',
#    'created_at': '2023-04-09T23:30:16.000Z',
#    'text': 'RT @elonmusk: @DavidSacks @VivekGRamaswamy @GregAbbott_TX Yeah, wrong on many levels. Tesla is increasing production rapidly in Texas, Cali…'},
#   {'edit_history_tweet_ids': ['1645207527821307904'],
#    'id': '1645207527821307904',
#    'lang': 'en',
#    'created_at': '2023-04-09T23:30:15.000Z',
#    'text': 'RT @teslacarsonly: THE DOPEST PHOTO OF TESLA SEMI TRUCK DELIVERING TESLAS.⚡ https://t.co/lCFOLVN7jk'},
#   {'edit_history_tweet_ids': ['1645207513745301504'],
#    'id': '1645207513745301504',
#    'lang': 'en',
#    'created_at': '2023-04-09T23:30:12.000Z',
#    'text': 'RT @garyblack00: Once ramped, this will effectively double $TSLA megapack capacity to 20K megapacks/year. That could be worth +$50B/yr new…'},
#   {'edit_history_tweet_ids': ['1645207511014821889'],
#    'id': '1645207511014821889',
#    'lang': 'en',
#    'created_at': '2023-04-09T23:30:11.000Z',
#    'text': '@EZebroni @Tesla Ahh makes sense'},
#   {'edit_history_tweet_ids': ['1645207503007883264'],
#    'id': '1645207503007883264',
#    'lang': 'en',
#    'created_at': '2023-04-09T23:30:09.000Z',
#    'text': 'Tesla Inc. is planning to install iron-based batteries that are not only cheaper, but less of a fire hazard, in a version of an affordable electric vehicle and a semi heavy electric truck, according to reports.  https://t.co/DUvOH1kDHQ'},
#   {'edit_history_tweet_ids': ['1645207499576860674'],
#    'id': '1645207499576860674',
#    'lang': 'en',
#    'created_at': '2023-04-09T23:30:09.000Z',
#    'text': 'The factory will initially produce 10,000 Megapack units a year, equal to around 40 gigawatt hours of #energy storage, to be sold globally. \n\n#Tesla #ElonMusk #BusinessNews #China #Shanghai  https://t.co/CAkVTRB9Qw'},
#   {'edit_history_tweet_ids': ['1645207497379119110'],
#    'id': '1645207497379119110',
#    'lang': 'en',
#    'created_at': '2023-04-09T23:30:08.000Z',
#    'text': 'RT @spieckerman: Great move for U.S. national security &amp; economy. Environmental benefits a crucial bonus.\n\nHigh U.S. gas consumption props-…'},
#   {'edit_history_tweet_ids': ['1645207494862729216'],
#    'id': '1645207494862729216',
#    'lang': 'en',
#    'created_at': '2023-04-09T23:30:07.000Z',
#    'text': 'RT @TeslaSynopsis: Happy Easter 🐰. Let the red Tesla bus take you for a ride! https://t.co/EWC7WggvsN'},
#   {'edit_history_tweet_ids': ['1645207489556692996'],
#    'id': '1645207489556692996',
#    'lang': 'en',
#    'created_at': '2023-04-09T23:30:06.000Z',
#    'text': 'Tesla Accused of Breaching Customer Privacy With Secretly Shared Camera Footage \n https://t.co/xV5IDhh58B'},
#   {'edit_history_tweet_ids': ['1645207485421158400'],
#    'id': '1645207485421158400',
#    'lang': 'en',
#    'created_at': '2023-04-09T23:30:05.000Z',
#    'text': "Elon Musk reveals plans for a new factory making Megapacks on Shanghai visit, while Apple mulls 'decoupling' from China https://t.co/kkIL13Ki97 #engineering #technology"},
#   {'edit_history_tweet_ids': ['1645207483043008512'],
#    'id': '1645207483043008512',
#    'lang': 'et',
#    'created_at': '2023-04-09T23:30:05.000Z',
#    'text': 'RT @Lucian240747241: Tesla head\n#fingering #pyt #ebony #blowjob #deepthroat #sloppy #slurping #gawkgawk #snowbunny #bimbo #latina #throat #…'},
#   {'edit_history_tweet_ids': ['1645207458204332034'],
#    'id': '1645207458204332034',
#    'lang': 'fr',
#    'created_at': '2023-04-09T23:29:59.000Z',
#    'text': 'RT @Angel_Gender: JOYEUX ANNIVERSAIRE TESLA\n#affiche 😜🤧🥳❤️🐱 https://t.co/u8w01Q1biS'},
#   {'edit_history_tweet_ids': ['1645207453976657921'],
#    'id': '1645207453976657921',
#    'lang': 'en',
#    'created_at': '2023-04-09T23:29:58.000Z',
#    'text': '@abhinav_kumarrr @elonmusk Well, Elon tried once. Very high tax on EVs in India, as much as 100% (15% in china) so a 50 L worth of a Tesla car would be sold at 1 cr here. Duties tax is also very high here in India compared to China and other countries🤷🏼\u200d♂️'},
#   {'edit_history_tweet_ids': ['1645207447135719424'],
#    'id': '1645207447135719424',
#    'lang': 'en',
#    'created_at': '2023-04-09T23:29:56.000Z',
#    'text': '@elonmusk @TimSweeneyEpic Will recognising different English accents come to @tesla soon?'},
#   {'edit_history_tweet_ids': ['1645207439925723136'],
#    'id': '1645207439925723136',
#    'lang': 'en',
#    'created_at': '2023-04-09T23:29:54.000Z',
#    'text': '@Tesla I avoid buying anything made in Communist China.'},
#   {'edit_history_tweet_ids': ['1645207436821774338'],
#    'id': '1645207436821774338',
#    'lang': 'en',
#    'created_at': '2023-04-09T23:29:54.000Z',
#    'text': 'RT @TheTaijiNews: @ZoeSchiffer Sounds like a familiar Elon business practice. https://t.co/zdI3XSUKdV'},
#   {'edit_history_tweet_ids': ['1645207423282552833'],
#    'id': '1645207423282552833',
#    'lang': 'en',
#    'created_at': '2023-04-09T23:29:50.000Z',
#    'text': "@MooseHornRiver @EDUESPANA @Tesla I don't feel like explaining to Musk. He can easily explain himself. However, if liberals really care that much about China's disrespect for human life, then stop speaking against the CCP on camera while doing business under the table with them! It’s common sense."},
#   {'edit_history_tweet_ids': ['1645207420354920451'],
#    'id': '1645207420354920451',
#    'lang': 'en',
#    'created_at': '2023-04-09T23:29:50.000Z',
#    'text': 'RT @peterdog15: Giga Texas is cranking out &amp; shipping more Model Ys than ever with 50 per hour based on my time here today! Berlin beware!!…'},
#   {'edit_history_tweet_ids': ['1645207420132634624'],
#    'id': '1645207420132634624',
#    'lang': 'es',
#    'created_at': '2023-04-09T23:29:50.000Z',
#    'text': '@renacova Dicen los hijos de tesla qué el único que los puede tratar como pendejos es Samuel García'},
#   {'edit_history_tweet_ids': ['1645207415472680964'],
#    'id': '1645207415472680964',
#    'lang': 'es',
#    'created_at': '2023-04-09T23:29:48.000Z',
#    'text': 'Tesla construirá una nueva fábrica de baterías en China #Expansioncom https://t.co/aayHX4FZHP'},
#   {'edit_history_tweet_ids': ['1645207413081948166'],
#    'id': '1645207413081948166',
#    'lang': 'en',
#    'created_at': '2023-04-09T23:29:48.000Z',
#    'text': 'RT @CNN: The factory will be able to produce 10,000 Megapacks — very large batteries used to store utility-scale amounts of electricity — p…'},
#   {'edit_history_tweet_ids': ['1645207409428766722'],
#    'id': '1645207409428766722',
#    'lang': 'qme',
#    'created_at': '2023-04-09T23:29:47.000Z',
#    'text': '@nachodelaheysus @tearsintherain1 @ALi3NKAT @StarshipDock @PryZmRuleZZ @TeslaDarth @Michaeldoge420 @QuantumFekT @IamCelineMarie @TheKatsKid1 @lottkaren54 @Lionelclone1 @safferpsyche @SpadersNFTs @AndreMillaire @Rajtwittz @DogeAccept @musicphantom69 @jewel_gardener @d1dave123 @dawnheartLRPS @sofakingdoge2nd @kym_head @YeshuaisSavior @PiaPanda96 @PleiadesPlZ @YadiraRussell9 @YOUniverse999 @MaximoBanksy @bugaloo_2 @13dogecoin @boozelee86 @h_artsNcrafts @MarshaW15161057 @codehurtsbrain @elonmusk @Tesla @Tesla_Megapack @Grimezsz @dogecoin @Nike @SpaceCrystalZ @historydefined @HistoryInPics @NelsonMandela @YourHomeMars @SpaceX 🔥🔥🔥'},
#   {'edit_history_tweet_ids': ['1645207398943014912'],
#    'id': '1645207398943014912',
#    'lang': 'en',
#    'withheld': {'copyright': False, 'country_codes': ['ID']},
#    'created_at': '2023-04-09T23:29:45.000Z',
#    'text': 'RT @ValaAfshar: @elonmusk If you want to find the secrets of the universe, think in terms of energy, frequency and vibration.\n\n—Nikola Tesl…'},
#   {'edit_history_tweet_ids': ['1645207397324009475'],
#    'id': '1645207397324009475',
#    'lang': 'en',
#    'created_at': '2023-04-09T23:29:44.000Z',
#    'text': 'RT @tearsintherain1: @nachodelaheysus @ALi3NKAT @StarshipDock @PryZmRuleZZ @TeslaDarth @Michaeldoge420 @QuantumFekT @IamCelineMarie @TheKat…'},
#   {'edit_history_tweet_ids': ['1645207394467868673'],
#    'id': '1645207394467868673',
#    'lang': 'en',
#    'created_at': '2023-04-09T23:29:43.000Z',
#    'text': '@AHCapMgmt @Jones1CDSR @Tesla More than offset. One is a strategy that bears have overplayed. This is development in the right direction. I m more of a longer term investor. I see further into the future. The bears r just making noises. Price cuts spur adoption.'},
#   {'edit_history_tweet_ids': ['1645207368953737218'],
#    'id': '1645207368953737218',
#    'lang': 'en',
#    'created_at': '2023-04-09T23:29:37.000Z',
#    'text': '@nachodelaheysus @ALi3NKAT @StarshipDock @PryZmRuleZZ @TeslaDarth @Michaeldoge420 @QuantumFekT @IamCelineMarie @TheKatsKid1 @lottkaren54 @Lionelclone1 @safferpsyche @memesus77 @SpadersNFTs @AndreMillaire @Rajtwittz @DogeAccept @musicphantom69 @jewel_gardener @d1dave123 @dawnheartLRPS @sofakingdoge2nd @kym_head @YeshuaisSavior @PiaPanda96 @PleiadesPlZ @YadiraRussell9 @YOUniverse999 @MaximoBanksy @bugaloo_2 @13dogecoin @boozelee86 @h_artsNcrafts @MarshaW15161057 @codehurtsbrain @elonmusk @Tesla @Tesla_Megapack @Grimezsz @dogecoin @Nike @SpaceCrystalZ @historydefined @HistoryInPics @NelsonMandela @YourHomeMars @SpaceX I just come here for the free food 🥘'},
#   {'edit_history_tweet_ids': ['1645207361349361666'],
#    'id': '1645207361349361666',
#    'lang': 'en',
#    'created_at': '2023-04-09T23:29:36.000Z',
#    'text': '@Rebecca61017020 Reach out to Big Tesla for direct access to free signals, Trade Analysis and mentorship programs\n✅\n\nhttps://t.co/ixpv0wQ7AS'},
#   {'edit_history_tweet_ids': ['1645207361118674944'],
#    'id': '1645207361118674944',
#    'lang': 'en',
#    'created_at': '2023-04-09T23:29:36.000Z',
#    'text': 'Wow, Tesla faces class action privacy lawsuit, following startling revelations https://t.co/I3h9DFdGOi'},
#   {'edit_history_tweet_ids': ['1645207354969931777'],
#    'id': '1645207354969931777',
#    'lang': 'en',
#    'created_at': '2023-04-09T23:29:34.000Z',
#    'text': 'If Elon Musk is from South Africa, why is Tesla building a huge battery factory in China? Why not locate such project in an African country where the labor is cheap, and will create job for Africans?'},
#   {'edit_history_tweet_ids': ['1645207349533999104'],
#    'id': '1645207349533999104',
#    'lang': 'en',
#    'created_at': '2023-04-09T23:29:33.000Z',
#    'text': '@elonmusk Tesla is not Alian car ? 🤔'},
#   {'edit_history_tweet_ids': ['1645207349110669313'],
#    'id': '1645207349110669313',
#    'lang': 'en',
#    'created_at': '2023-04-09T23:29:33.000Z',
#    'text': 'RT @maskofbun: the fact that this concept art was supposed to be vash 1) shows how much he resembles tesla and aligns with the theory that…'},
#   {'edit_history_tweet_ids': ['1645207348548452354'],
#    'id': '1645207348548452354',
#    'lang': 'en',
#    'created_at': '2023-04-09T23:29:33.000Z',
#    'text': 'RT @nytimes: Tesla will build a factory in Shanghai to manufacture its large-scale energy-storage batteries known as the Megapack, the Chin…'},
#   {'edit_history_tweet_ids': ['1645207341858471942'],
#    'id': '1645207341858471942',
#    'lang': 'en',
#    'created_at': '2023-04-09T23:29:31.000Z',
#    'text': '@AryanPigkaw Do Einstein and Tesla have competing claims?'},
#   {'edit_history_tweet_ids': ['1645207339840987136'],
#    'id': '1645207339840987136',
#    'lang': 'en',
#    'created_at': '2023-04-09T23:29:30.000Z',
#    'text': 'RT @ZainulA36741500: @elonmusk @SawyerMerritt @Tesla Alerts crypto trader! They predicted that Bitcoin could fall to $5,000 levels in 2023.…'},
#   {'edit_history_tweet_ids': ['1645207339740418050'],
#    'id': '1645207339740418050',
#    'lang': 'en',
#    'created_at': '2023-04-09T23:29:30.000Z',
#    'text': 'RT @6abc: A Tesla owner filed a complaint accusing the company of allegedly violating California privacy laws, among other claims.  https:/…'},
#   {'edit_history_tweet_ids': ['1645207336602988544'],
#    'id': '1645207336602988544',
#    'lang': 'en',
#    'created_at': '2023-04-09T23:29:30.000Z',
#    'text': 'RT @Vespa_sa_gedli: Tesla -1.12%, Apple -0.33%, AI -26.34%, AMC -23.48%, Dow Jones Industrial -198 pts, Bitcoin 28,226 https://t.co/YM7CtC9…'},
#   {'edit_history_tweet_ids': ['1645207335005036544'],
#    'id': '1645207335005036544',
#    'lang': 'en',
#    'created_at': '2023-04-09T23:29:29.000Z',
#    'text': '@VivekGRamaswamy @elonmusk Megapack has nothing to do with EVs. It’s grid-scale battery storage. Also EVs for American consumers are made in America in Tesla’s factories in California, Nevada and Texas'},
#   {'edit_history_tweet_ids': ['1645207331242639363'],
#    'id': '1645207331242639363',
#    'lang': 'en',
#    'created_at': '2023-04-09T23:29:28.000Z',
#    'text': 'RT @SaycheeseDGTL: 😢 Former Tesla worker Owen Diaz was awarded $137M last year for dealing with racism on the job “The supervisor called hi…'},
#   {'edit_history_tweet_ids': ['1645207330466803714'],
#    'id': '1645207330466803714',
#    'lang': 'en',
#    'created_at': '2023-04-09T23:29:28.000Z',
#    'text': 'RT @IEEESpectrum: Developing cells for drones and air taxis is one way to achieve lightweight battery breakthroughs. This company has doubl…'},
#   {'edit_history_tweet_ids': ['1645207324993417216'],
#    'id': '1645207324993417216',
#    'lang': 'en',
#    'created_at': '2023-04-09T23:29:27.000Z',
#    'text': "RT @MuskUniversity: “Focus on signal over noise. A lot of companies get confused, they spend money on things that don't actually make the p…"},
#   {'edit_history_tweet_ids': ['1645207311894339585'],
#    'id': '1645207311894339585',
#    'lang': 'en',
#    'created_at': '2023-04-09T23:29:24.000Z',
#    'text': 'RT @DillonLoomis22: A lot of chatter about $TSLA growth rates slowing, demand falling, advertising needs etc. \n\nNot to oversimplify, but ca…'},
#   {'edit_history_tweet_ids': ['1645207308513812480'],
#    'id': '1645207308513812480',
#    'lang': 'en',
#    'created_at': '2023-04-09T23:29:23.000Z',
#    'text': 'RT @factchecking18: "We’ll also go after the Wall St short-sellers ... "\n\nSaid the $DOGE-pump-master 🤣\n\n#Musk \n#Tesla \n#Bitcoin https://t.c…'},
#   {'edit_history_tweet_ids': ['1645207305708015620'],
#    'id': '1645207305708015620',
#    'lang': 'en',
#    'created_at': '2023-04-09T23:29:22.000Z',
#    'text': '@MeniTsirbas @CornelyTristan @LucidMotors @Tesla not devoted to any company. $TSLA is my biggest investment followed by $LCID (distant 2nd) &amp; RIVN. love good engineering and making money. Just want to end this by saying, in 2023, a company with a stunning EV will make it. 86% auto market share still there for EVs to capture. GD'}],
#  'meta': {'newest_id': '1645207791890513920',
#   'oldest_id': '1645207305708015620',
#   'result_count': 100,
#   'next_token': 'b26v89c19zqg8o3fqkd0rv6ra1xqnha3sda67dqr6zgjh'}}

# %% [markdown]
# This data is messy and notreadable.

# %% [markdown]
# ___

# %% [markdown]
# # Reading and Storing the Data

# %% [markdown]
# `.json()` converts the response to a Python directory.
# - we access dictionary key-value pairs using the `['key']` syntax

# %%
str(response.json())[:500]
# Out:
# '{\'data\': [{\'edit_history_tweet_ids\': [\'1645207791890513920\'], \'id\': \'1645207791890513920\', \'lang\': \'en\', \'created_at\': \'2023-04-09T23:31:18.000Z\', \'text\': "@memesus77 @tearsintherain1 @ALi3NKAT @StarshipDock @PryZmRuleZZ @TeslaDarth @Michaeldoge420 @QuantumFekT @IamCelineMarie @TheKatsKid1 @lottkaren54 @Lionelclone1 @safferpsyche @SpadersNFTs @AndreMillaire @Rajtwittz @DogeAccept @musicphantom69 @jewel_gardener @d1dave123 @dawnheartLRPS @sofakingdoge2nd @kym_head @YeshuaisSavior @PiaPanda96 @Ple'

# %%
response.json()['data']
# Out:
# [{'edit_history_tweet_ids': ['1645207791890513920'],
#   'id': '1645207791890513920',
#   'lang': 'en',
#   'created_at': '2023-04-09T23:31:18.000Z',
#   'text': "@memesus77 @tearsintherain1 @ALi3NKAT @StarshipDock @PryZmRuleZZ @TeslaDarth @Michaeldoge420 @QuantumFekT @IamCelineMarie @TheKatsKid1 @lottkaren54 @Lionelclone1 @safferpsyche @SpadersNFTs @AndreMillaire @Rajtwittz @DogeAccept @musicphantom69 @jewel_gardener @d1dave123 @dawnheartLRPS @sofakingdoge2nd @kym_head @YeshuaisSavior @PiaPanda96 @PleiadesPlZ @YadiraRussell9 @YOUniverse999 @MaximoBanksy @bugaloo_2 @13dogecoin @boozelee86 @h_artsNcrafts @MarshaW15161057 @codehurtsbrain @elonmusk @Tesla @Tesla_Megapack @Grimezsz @dogecoin @Nike @SpaceCrystalZ @historydefined @HistoryInPics @NelsonMandela @YourHomeMars @SpaceX Is everyone scheduled and excited for bear hug Thursday it's coming up ya know....\n\nSigh 😕 https://t.co/btJxNITJuH"},
#  {'edit_history_tweet_ids': ['1645207779123118080'],
#   'id': '1645207779123118080',
#   'lang': 'qme',
#   'created_at': '2023-04-09T23:31:15.000Z',
#   'text': '@SawyerMerritt @Tesla https://t.co/r0f31PhSxb'},
#  {'edit_history_tweet_ids': ['1645207775113523203'],
#   'id': '1645207775113523203',
#   'lang': 'qme',
#   'created_at': '2023-04-09T23:31:14.000Z',
#   'text': '@Nikola_Truth @blueskykites @TeslaUniverse_ @Tesla @WholeMarsBlog @Kristennetten @S4njuBajaj @teardowntitan @WestTeslarado @PauljHorton @atk0506 @WIsitlike @mundanemun @Amy_Sober @TeslaDiva99 @R6Alex @shortword @1stMarsColonist @CorySteuben @MadTorque @JhonnyOnasis @MobofJoggers @InchaustiRon 🥳🚀♥️'},
#  {'edit_history_tweet_ids': ['1645207772248653824'],
#   'id': '1645207772248653824',
#   'lang': 'qam',
#   'created_at': '2023-04-09T23:31:14.000Z',
#   'text': '@Tesla @elonmusk @NissanElectric @ford @Rivian @ENERGY @environmentca @cbc @CTVNews @JustinTrudeau @JoeBiden https://t.co/78LuPzk5k8'},
#  {'edit_history_tweet_ids': ['1645207760634626048'],
#   'id': '1645207760634626048',
#   'lang': 'und',
#   'created_at': '2023-04-09T23:31:11.000Z',
#   'text': '@memesus77 @nachodelaheysus @ALi3NKAT @StarshipDock @PryZmRuleZZ @TeslaDarth @Michaeldoge420 @QuantumFekT @IamCelineMarie @TheKatsKid1 @lottkaren54 @Lionelclone1 @safferpsyche @SpadersNFTs @AndreMillaire @Rajtwittz @DogeAccept @musicphantom69 @jewel_gardener @d1dave123 @dawnheartLRPS @sofakingdoge2nd @kym_head @YeshuaisSavior @PiaPanda96 @PleiadesPlZ @YadiraRussell9 @YOUniverse999 @MaximoBanksy @bugaloo_2 @13dogecoin @boozelee86 @h_artsNcrafts @MarshaW15161057 @codehurtsbrain @elonmusk @Tesla @Tesla_Megapack @Grimezsz @dogecoin @Nike @SpaceCrystalZ @historydefined @HistoryInPics @NelsonMandela @YourHomeMars @SpaceX Lol 😝'},
#  {'edit_history_tweet_ids': ['1645207751646392320'],
#   'id': '1645207751646392320',
#   'lang': 'en',
#   'created_at': '2023-04-09T23:31:09.000Z',
#   'text': 'RT @elonmusk: @DavidSacks @VivekGRamaswamy @GregAbbott_TX Yeah, wrong on many levels. Tesla is increasing production rapidly in Texas, Cali…'},
#  {'edit_history_tweet_ids': ['1645207748722798592'],
#   'id': '1645207748722798592',
#   'lang': 'en',
#   'created_at': '2023-04-09T23:31:08.000Z',
#   'text': '@hyteckit @farzyness The big one with these Tesla cars that everybody seems to forget is to check the blinker fluid.'},
#  {'edit_history_tweet_ids': ['1645207748362084356'],
#   'id': '1645207748362084356',
#   'lang': 'en',
#   'created_at': '2023-04-09T23:31:08.000Z',
#   'text': '@indigenoussista He originally brought the fight to Tesla on his own.  Then a Blk female HR filed her complaint after his lawyers case was set for settlement before he won in court.  She was in HR and did nothing the entire time but ignore the racist actions of the management team.'},
#  {'edit_history_tweet_ids': ['1645207743375220736'],
#   'id': '1645207743375220736',
#   'lang': 'zh',
#   'created_at': '2023-04-09T23:31:07.000Z',
#   'text': 'Tesla 人形機器人\n\nhttps://t.co/984T8usZB8'},
#  {'edit_history_tweet_ids': ['1645207738446651392'],
#   'id': '1645207738446651392',
#   'lang': 'en',
#   'created_at': '2023-04-09T23:31:05.000Z',
#   'text': 'RT @SaycheeseDGTL: 😢 Former Tesla worker Owen Diaz was awarded $137M last year for dealing with racism on the job “The supervisor called hi…'},
#  {'edit_history_tweet_ids': ['1645207728627875843'],
#   'id': '1645207728627875843',
#   'lang': 'en',
#   'created_at': '2023-04-09T23:31:03.000Z',
#   'text': '@msaunby @KaramMacro @ParikPatelCFA @RobinWigg Yeah Tesla just seems like they are dogshit and plummeting every day. Get off Twitter @elonmusk  😂'},
#  {'edit_history_tweet_ids': ['1645207725368803330'],
#   'id': '1645207725368803330',
#   'lang': 'en',
#   'created_at': '2023-04-09T23:31:02.000Z',
#   'text': '@elonmusk @WallStreetSilv will Tesla have a "government funded car company" added to it\'s twitter account?'},
#  {'edit_history_tweet_ids': ['1645207720478294023'],
#   'id': '1645207720478294023',
#   'lang': 'en',
#   'created_at': '2023-04-09T23:31:01.000Z',
#   'text': '@wieslawawy @HankMeninga @Tesla @elonmusk I only buy clothes made in South Asia because they allow child labor. I think children make better clothes'},
#  {'edit_history_tweet_ids': ['1645207710055407619'],
#   'id': '1645207710055407619',
#   'lang': 'en',
#   'created_at': '2023-04-09T23:30:59.000Z',
#   'text': '@teslamarge @DimaZeniuk @teslaownersSV @Tesla @elonmusk @TeslaNY @klwtts @WholeMarsBlog @DriveTeslaca @BrandonTSLA Ya, wheels can be changed just get me that truck asap.'},
#  {'edit_history_tweet_ids': ['1645207707304034315'],
#   'id': '1645207707304034315',
#   'lang': 'es',
#   'created_at': '2023-04-09T23:30:58.000Z',
#   'text': 'RT @TeslaSynopsis: Tesla autopark\nhttps://t.co/B2s60FGWFu'},
#  {'edit_history_tweet_ids': ['1645207706897113089'],
#   'id': '1645207706897113089',
#   'lang': 'en',
#   'created_at': '2023-04-09T23:30:58.000Z',
#   'text': 'RT @EvaFoxU: Tesla has installed 45,000 Supercharger stalls worldwide, greatly accelerating the pace of rollout in recent months ⚡️⚡️⚡️ Cha…'},
#  {'edit_history_tweet_ids': ['1645207704544198659'],
#   'id': '1645207704544198659',
#   'lang': 'qme',
#   'created_at': '2023-04-09T23:30:57.000Z',
#   'text': 'RT @JCOviedo6: $TSLA\n\nhttps://t.co/ARdMWAjkf3'},
#  {'edit_history_tweet_ids': ['1645207694436081664'],
#   'id': '1645207694436081664',
#   'lang': 'en',
#   'created_at': '2023-04-09T23:30:55.000Z',
#   'text': '@AndyBxxx 4. Tesla argues that it would increase density but this is due to the size of the cell and not the actual density of the battery and if any is simply following some small increase along with the rest of the world.\n\nEVs "help", but cannot be on the same league as trains. https://t.co/0pRVe0RBU9'},
#  {'edit_history_tweet_ids': ['1645207694364536832'],
#   'id': '1645207694364536832',
#   'lang': 'tr',
#   'created_at': '2023-04-09T23:30:55.000Z',
#   'text': 'RT @asenardic: gelecekteki kocam eğer yazılımcıysan Tesla işi sende ben evimize kek kalıbı aldım param bitti'},
#  {'edit_history_tweet_ids': ['1645207677067247618'],
#   'id': '1645207677067247618',
#   'lang': 'en',
#   'created_at': '2023-04-09T23:30:51.000Z',
#   'text': '#Ahead Of #Elon Musk’s #Rumored #China Visit, #Report Says #Tesla Will #Set Up New #Shanghai #Plant To #Manufacture #Megapacks – Tesla (NASDAQ:TSLA) https://t.co/L3kcOWBxQ0 #musks #nasdaqtsla #visit'},
#  {'edit_history_tweet_ids': ['1645207676043788288'],
#   'id': '1645207676043788288',
#   'lang': 'en',
#   'created_at': '2023-04-09T23:30:51.000Z',
#   'text': 'How come congress not goin question Elon https://t.co/H2MVmXkunj'},
#  {'edit_history_tweet_ids': ['1645207674244698113'],
#   'id': '1645207674244698113',
#   'lang': 'en',
#   'created_at': '2023-04-09T23:30:50.000Z',
#   'text': "RT @GunnelsWarren: Funny. Every time Elon Musk pretends to be a self-made billionaire remember: He'd be worth $0 without $4.9 billion in co…"},
#  {'edit_history_tweet_ids': ['1645207671744737281'],
#   'id': '1645207671744737281',
#   'lang': 'en',
#   'created_at': '2023-04-09T23:30:50.000Z',
#   'text': '@Tesla Wrong direction'},
#  {'edit_history_tweet_ids': ['1645207667160530945'],
#   'id': '1645207667160530945',
#   'lang': 'en',
#   'created_at': '2023-04-09T23:30:48.000Z',
#   'text': "@dvorahfr @elonmusk @DavidSacks @VivekGRamaswamy @GregAbbott_TX that's a truly idiotic cartoon.  Both Biden (whom is not a 'radical left') AND elon/tesla are dramatically making progress towards reducing our dependency on and use of fossil fuels."},
#  {'edit_history_tweet_ids': ['1645207666913054720'],
#   'id': '1645207666913054720',
#   'lang': 'es',
#   'created_at': '2023-04-09T23:30:48.000Z',
#   'text': 'Mientras en 🇵🇷pendiente al mantengo.. “Muchos acuerdos han aterrizado en 🇲🇽: Tesla, la empresa electrónica taiwanesa Quanta, expansión del fabricante italiano de frenos Brembo, y un acuerdo de la alemana BMW para producir baterías y autos eléctricos. \n\nhttps://t.co/YPZOSIPiUr'},
#  {'edit_history_tweet_ids': ['1645207664719265792'],
#   'id': '1645207664719265792',
#   'lang': 'es',
#   'created_at': '2023-04-09T23:30:48.000Z',
#   'text': 'RT @MDCamacaro: #DomingoDeReencuentro\nTesla construirá una fábrica de baterías Megapack en Shanghái'},
#  {'edit_history_tweet_ids': ['1645207662248747010'],
#   'id': '1645207662248747010',
#   'lang': 'en',
#   'created_at': '2023-04-09T23:30:47.000Z',
#   'text': 'RT @SaycheeseDGTL: 😢 Former Tesla worker Owen Diaz was awarded $137M last year for dealing with racism on the job “The supervisor called hi…'},
#  {'edit_history_tweet_ids': ['1645207653415796736'],
#   'id': '1645207653415796736',
#   'lang': 'en',
#   'created_at': '2023-04-09T23:30:45.000Z',
#   'text': '@mundanemun @blueskykites @TeslaUniverse_ @Tesla @WholeMarsBlog @Kristennetten @S4njuBajaj @teardowntitan @WestTeslarado @PauljHorton @atk0506 @WIsitlike @Amy_Sober @TeslaDiva99 @R6Alex @shortword @Nikola_Truth @1stMarsColonist @CorySteuben @MadTorque @JhonnyOnasis @MobofJoggers @InchaustiRon 🤗♥️\n\nHowever too little photos of you and me…! 😂'},
#  {'edit_history_tweet_ids': ['1645207649061941248'],
#   'id': '1645207649061941248',
#   'lang': 'es',
#   'created_at': '2023-04-09T23:30:44.000Z',
#   'text': 'RT @Chavista0101: #DomingoDeReencuentro\nTesla construirá una fábrica de baterías Megapack en Shanghái'},
#  {'edit_history_tweet_ids': ['1645207644410642432'],
#   'id': '1645207644410642432',
#   'lang': 'en',
#   'created_at': '2023-04-09T23:30:43.000Z',
#   'text': '@engineers_feed by faith: 2024 AD   @Tesla Sub.   already an ev\nnot too much of a stretch. and eARTh is 70% water.\nlmk?'},
#  {'edit_history_tweet_ids': ['1645207637020250112'],
#   'id': '1645207637020250112',
#   'lang': 'qme',
#   'created_at': '2023-04-09T23:30:41.000Z',
#   'text': 'RT @memesus77: @tearsintherain1 @nachodelaheysus @ALi3NKAT @StarshipDock @PryZmRuleZZ @TeslaDarth @Michaeldoge420 @QuantumFekT @IamCelineMa…'},
#  {'edit_history_tweet_ids': ['1645207636852330501'],
#   'id': '1645207636852330501',
#   'lang': 'en',
#   'created_at': '2023-04-09T23:30:41.000Z',
#   'text': '@gabbie_tesla Mario Bros, Mario Kart, &amp; Street Fighter'},
#  {'edit_history_tweet_ids': ['1645207628153499648'],
#   'id': '1645207628153499648',
#   'lang': 'en',
#   'created_at': '2023-04-09T23:30:39.000Z',
#   'text': 'RT @DarrigoMelanie: Tesla, SpaceX and SolarCity received at least $4.9 Billion in government subsidies, and more in tax breaks.\n\nBy compari…'},
#  {'edit_history_tweet_ids': ['1645207627117510662'],
#   'id': '1645207627117510662',
#   'lang': 'en',
#   'created_at': '2023-04-09T23:30:39.000Z',
#   'text': 'RT @Tslachan: $TSLA @elonmusk \n* Can We Think Of The exponential Growth Of Tesla Megapack?\n🗣️ Elon : energy storage business will grow fast…'},
#  {'edit_history_tweet_ids': ['1645207616589529088'],
#   'id': '1645207616589529088',
#   'lang': 'en',
#   'created_at': '2023-04-09T23:30:36.000Z',
#   'text': 'RT @DarrigoMelanie: Tesla, SpaceX and SolarCity received at least $4.9 Billion in government subsidies, and more in tax breaks.\n\nBy compari…'},
#  {'edit_history_tweet_ids': ['1645207612328214529'],
#   'id': '1645207612328214529',
#   'lang': 'en',
#   'created_at': '2023-04-09T23:30:35.000Z',
#   'text': 'RT @SawyerMerritt: BREAKING: @Tesla will build a Megapack factory in Shanghai, Chinese state media outlet Xinhua reported on Sunday.\n\nConst…'},
#  {'edit_history_tweet_ids': ['1645207611791523840'],
#   'id': '1645207611791523840',
#   'lang': 'en',
#   'created_at': '2023-04-09T23:30:35.000Z',
#   'text': '#TWITTER?\n#OnTheINTERNETcreatddBy #DARPA\n#CreatedByFundingLegislation passed by #CONGRESS\n#ALGORE\n#SPACEX #GOVERNMENTFUNDED contracted SPACE BUS?\n#TESLA sold with #GOVERNMENTfunded INCENTIVE PROGRAMS. Driving on streets created and maintained by #GOVERNMENTFUNDING'},
#  {'edit_history_tweet_ids': ['1645207610176438272'],
#   'id': '1645207610176438272',
#   'lang': 'en',
#   'created_at': '2023-04-09T23:30:35.000Z',
#   'text': 'RT @SaycheeseDGTL: 😢 Former Tesla worker Owen Diaz was awarded $137M last year for dealing with racism on the job “The supervisor called hi…'},
#  {'edit_history_tweet_ids': ['1645207608851038209'],
#   'id': '1645207608851038209',
#   'lang': 'en',
#   'created_at': '2023-04-09T23:30:35.000Z',
#   'text': 'RT @elonmusk: Wait for it …'},
#  {'edit_history_tweet_ids': ['1645207605986357251'],
#   'id': '1645207605986357251',
#   'lang': 'en',
#   'created_at': '2023-04-09T23:30:34.000Z',
#   'text': 'RT @DarrigoMelanie: Tesla, SpaceX and SolarCity received at least $4.9 Billion in government subsidies, and more in tax breaks.\n\nBy compari…'},
#  {'edit_history_tweet_ids': ['1645207600449966080'],
#   'id': '1645207600449966080',
#   'lang': 'en',
#   'created_at': '2023-04-09T23:30:33.000Z',
#   'text': "RT @0ccultbot: Many of Nikola Tesla's most important inventions have NEVER been released to the public and never will be."},
#  {'edit_history_tweet_ids': ['1645207598185218048'],
#   'id': '1645207598185218048',
#   'lang': 'en',
#   'created_at': '2023-04-09T23:30:32.000Z',
#   'text': 'RT @LuisT5553: Tesla malfunctions on highway, stops, starts smoking, and explodes roughly 16 times. EVs are bombs waiting to go off. 😳😳😳😳😳😲…'},
#  {'edit_history_tweet_ids': ['1645207595878055936'],
#   'id': '1645207595878055936',
#   'lang': 'es',
#   'created_at': '2023-04-09T23:30:31.000Z',
#   'text': 'RT @pigdemont_: Si tienes un Tesla y te da un calentón con la parienta, mejor te es esperas a llegar a casa. https://t.co/N8bVepxxGa'},
#  {'edit_history_tweet_ids': ['1645207585476231170'],
#   'id': '1645207585476231170',
#   'lang': 'en',
#   'created_at': '2023-04-09T23:30:29.000Z',
#   'text': 'RT @SaycheeseDGTL: 😢 Former Tesla worker Owen Diaz was awarded $137M last year for dealing with racism on the job “The supervisor called hi…'},
#  {'edit_history_tweet_ids': ['1645207581428686849'],
#   'id': '1645207581428686849',
#   'lang': 'en',
#   'created_at': '2023-04-09T23:30:28.000Z',
#   'text': 'RT @Tesla: Our next Megafactory will be in Shanghai 🇨🇳—capable of producing 10k Megapacks per year https://t.co/KlVGq5gYOg'},
#  {'edit_history_tweet_ids': ['1645207576064282624'],
#   'id': '1645207576064282624',
#   'lang': 'en',
#   'created_at': '2023-04-09T23:30:27.000Z',
#   'text': 'RT @EvaFoxU: Tesla has installed 45,000 Supercharger stalls worldwide, greatly accelerating the pace of rollout in recent months ⚡️⚡️⚡️ Cha…'},
#  {'edit_history_tweet_ids': ['1645207568938328064'],
#   'id': '1645207568938328064',
#   'lang': 'ja',
#   'created_at': '2023-04-09T23:30:25.000Z',
#   'text': 'RT @16kthir0GRXgNqn: テスラ 上海にメガパックエネルギー貯蔵製品の工場を建設する予定https://t.co/m89uZ72qbh\n\n #テスラ\u3000#テスラ株 #イーロンマスク #elonmusk #cybertruck\u3000#chatgpt  #openai…'},
#  {'edit_history_tweet_ids': ['1645207564647563265'],
#   'id': '1645207564647563265',
#   'lang': 'en',
#   'created_at': '2023-04-09T23:30:24.000Z',
#   'text': "Elon Musk has produced a techno track about NFTs he's selling as an NFT.\nhttps://t.co/2CWBDA1qA7"},
#  {'edit_history_tweet_ids': ['1645207564433645568'],
#   'id': '1645207564433645568',
#   'lang': 'en',
#   'created_at': '2023-04-09T23:30:24.000Z',
#   'text': 'RT @DimaZeniuk: Tesla Cybertruck spotted in Fremont ⚡\U0001fa76\n\n📸: @teslaownersSV \n@Tesla @elonmusk https://t.co/GrVnOIUU9r'},
#  {'edit_history_tweet_ids': ['1645207558901170179'],
#   'id': '1645207558901170179',
#   'lang': 'qme',
#   'created_at': '2023-04-09T23:30:23.000Z',
#   'text': '@tearsintherain1 @nachodelaheysus @ALi3NKAT @StarshipDock @PryZmRuleZZ @TeslaDarth @Michaeldoge420 @QuantumFekT @IamCelineMarie @TheKatsKid1 @lottkaren54 @Lionelclone1 @safferpsyche @SpadersNFTs @AndreMillaire @Rajtwittz @DogeAccept @musicphantom69 @jewel_gardener @d1dave123 @dawnheartLRPS @sofakingdoge2nd @kym_head @YeshuaisSavior @PiaPanda96 @PleiadesPlZ @YadiraRussell9 @YOUniverse999 @MaximoBanksy @bugaloo_2 @13dogecoin @boozelee86 @h_artsNcrafts @MarshaW15161057 @codehurtsbrain @elonmusk @Tesla @Tesla_Megapack @Grimezsz @dogecoin @Nike @SpaceCrystalZ @historydefined @HistoryInPics @NelsonMandela @YourHomeMars @SpaceX 😋'},
#  {'edit_history_tweet_ids': ['1645207556078419968'],
#   'id': '1645207556078419968',
#   'lang': 'en',
#   'created_at': '2023-04-09T23:30:22.000Z',
#   'text': '@Zclove2bme @Tesla What did I miss?'},
#  {'edit_history_tweet_ids': ['1645207554388099073'],
#   'id': '1645207554388099073',
#   'lang': 'es',
#   'created_at': '2023-04-09T23:30:22.000Z',
#   'text': '💰 Tesla impulsa inversión en China y anuncia nueva fábrica de baterías a gran escala en Shanghái https://t.co/paYRWUKN7j https://t.co/sMe551Nw19'},
#  {'edit_history_tweet_ids': ['1645207551749890048'],
#   'id': '1645207551749890048',
#   'lang': 'en',
#   'created_at': '2023-04-09T23:30:21.000Z',
#   'text': 'RT @patel_patriot: Did you know China’s CATL, the worlds largest producer of lithium batteries, has a deal to provide batteries to Tesla?…'},
#  {'edit_history_tweet_ids': ['1645207551624073217'],
#   'id': '1645207551624073217',
#   'lang': 'en',
#   'created_at': '2023-04-09T23:30:21.000Z',
#   'text': 'RT @DarrigoMelanie: Tesla, SpaceX and SolarCity received at least $4.9 Billion in government subsidies, and more in tax breaks.\n\nBy compari…'},
#  {'edit_history_tweet_ids': ['1645207544376205312'],
#   'id': '1645207544376205312',
#   'lang': 'es',
#   'withheld': {'copyright': False,
#    'country_codes': ['AT',
#     'BE',
#     'BG',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'EE',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'HR',
#     'HU',
#     'IE',
#     'IT',
#     'LT',
#     'LU',
#     'LV',
#     'MT',
#     'NL',
#     'PL',
#     'PT',
#     'RO',
#     'SE',
#     'SI',
#     'SK']},
#   'created_at': '2023-04-09T23:30:19.000Z',
#   'text': 'RT @ActualidadRT: Tesla construirá una fábrica de baterías Megapack en Shanghái\n\nSe espera que produzca inicialmente 10.000 unidades por añ…'},
#  {'edit_history_tweet_ids': ['1645207543239835648'],
#   'id': '1645207543239835648',
#   'lang': 'ja',
#   'created_at': '2023-04-09T23:30:19.000Z',
#   'text': 'テスラ 上海にメガパックエネルギー貯蔵製品の工場を建設する予定https://t.co/m89uZ72qbh\n\n #テスラ\u3000#テスラ株 #イーロンマスク #elonmusk #cybertruck\u3000#chatgpt  #openai  #microsoft  #google #TSLA #Tesla #Model3 #ModelY #ModelS #ModelX #ロボタクシー  #投資 #資産運用 #EV #AI #暗号資産'},
#  {'edit_history_tweet_ids': ['1645207541062725635'],
#   'id': '1645207541062725635',
#   'lang': 'en',
#   'created_at': '2023-04-09T23:30:18.000Z',
#   'text': 'RT @elonmusk: Tesla opening Megapack factory in Shanghai to supplement output of Megapack factory in California'},
#  {'edit_history_tweet_ids': ['1645207531680088065'],
#   'id': '1645207531680088065',
#   'lang': 'en',
#   'created_at': '2023-04-09T23:30:16.000Z',
#   'text': 'RT @elonmusk: @DavidSacks @VivekGRamaswamy @GregAbbott_TX Yeah, wrong on many levels. Tesla is increasing production rapidly in Texas, Cali…'},
#  {'edit_history_tweet_ids': ['1645207527821307904'],
#   'id': '1645207527821307904',
#   'lang': 'en',
#   'created_at': '2023-04-09T23:30:15.000Z',
#   'text': 'RT @teslacarsonly: THE DOPEST PHOTO OF TESLA SEMI TRUCK DELIVERING TESLAS.⚡ https://t.co/lCFOLVN7jk'},
#  {'edit_history_tweet_ids': ['1645207513745301504'],
#   'id': '1645207513745301504',
#   'lang': 'en',
#   'created_at': '2023-04-09T23:30:12.000Z',
#   'text': 'RT @garyblack00: Once ramped, this will effectively double $TSLA megapack capacity to 20K megapacks/year. That could be worth +$50B/yr new…'},
#  {'edit_history_tweet_ids': ['1645207511014821889'],
#   'id': '1645207511014821889',
#   'lang': 'en',
#   'created_at': '2023-04-09T23:30:11.000Z',
#   'text': '@EZebroni @Tesla Ahh makes sense'},
#  {'edit_history_tweet_ids': ['1645207503007883264'],
#   'id': '1645207503007883264',
#   'lang': 'en',
#   'created_at': '2023-04-09T23:30:09.000Z',
#   'text': 'Tesla Inc. is planning to install iron-based batteries that are not only cheaper, but less of a fire hazard, in a version of an affordable electric vehicle and a semi heavy electric truck, according to reports.  https://t.co/DUvOH1kDHQ'},
#  {'edit_history_tweet_ids': ['1645207499576860674'],
#   'id': '1645207499576860674',
#   'lang': 'en',
#   'created_at': '2023-04-09T23:30:09.000Z',
#   'text': 'The factory will initially produce 10,000 Megapack units a year, equal to around 40 gigawatt hours of #energy storage, to be sold globally. \n\n#Tesla #ElonMusk #BusinessNews #China #Shanghai  https://t.co/CAkVTRB9Qw'},
#  {'edit_history_tweet_ids': ['1645207497379119110'],
#   'id': '1645207497379119110',
#   'lang': 'en',
#   'created_at': '2023-04-09T23:30:08.000Z',
#   'text': 'RT @spieckerman: Great move for U.S. national security &amp; economy. Environmental benefits a crucial bonus.\n\nHigh U.S. gas consumption props-…'},
#  {'edit_history_tweet_ids': ['1645207494862729216'],
#   'id': '1645207494862729216',
#   'lang': 'en',
#   'created_at': '2023-04-09T23:30:07.000Z',
#   'text': 'RT @TeslaSynopsis: Happy Easter 🐰. Let the red Tesla bus take you for a ride! https://t.co/EWC7WggvsN'},
#  {'edit_history_tweet_ids': ['1645207489556692996'],
#   'id': '1645207489556692996',
#   'lang': 'en',
#   'created_at': '2023-04-09T23:30:06.000Z',
#   'text': 'Tesla Accused of Breaching Customer Privacy With Secretly Shared Camera Footage \n https://t.co/xV5IDhh58B'},
#  {'edit_history_tweet_ids': ['1645207485421158400'],
#   'id': '1645207485421158400',
#   'lang': 'en',
#   'created_at': '2023-04-09T23:30:05.000Z',
#   'text': "Elon Musk reveals plans for a new factory making Megapacks on Shanghai visit, while Apple mulls 'decoupling' from China https://t.co/kkIL13Ki97 #engineering #technology"},
#  {'edit_history_tweet_ids': ['1645207483043008512'],
#   'id': '1645207483043008512',
#   'lang': 'et',
#   'created_at': '2023-04-09T23:30:05.000Z',
#   'text': 'RT @Lucian240747241: Tesla head\n#fingering #pyt #ebony #blowjob #deepthroat #sloppy #slurping #gawkgawk #snowbunny #bimbo #latina #throat #…'},
#  {'edit_history_tweet_ids': ['1645207458204332034'],
#   'id': '1645207458204332034',
#   'lang': 'fr',
#   'created_at': '2023-04-09T23:29:59.000Z',
#   'text': 'RT @Angel_Gender: JOYEUX ANNIVERSAIRE TESLA\n#affiche 😜🤧🥳❤️🐱 https://t.co/u8w01Q1biS'},
#  {'edit_history_tweet_ids': ['1645207453976657921'],
#   'id': '1645207453976657921',
#   'lang': 'en',
#   'created_at': '2023-04-09T23:29:58.000Z',
#   'text': '@abhinav_kumarrr @elonmusk Well, Elon tried once. Very high tax on EVs in India, as much as 100% (15% in china) so a 50 L worth of a Tesla car would be sold at 1 cr here. Duties tax is also very high here in India compared to China and other countries🤷🏼\u200d♂️'},
#  {'edit_history_tweet_ids': ['1645207447135719424'],
#   'id': '1645207447135719424',
#   'lang': 'en',
#   'created_at': '2023-04-09T23:29:56.000Z',
#   'text': '@elonmusk @TimSweeneyEpic Will recognising different English accents come to @tesla soon?'},
#  {'edit_history_tweet_ids': ['1645207439925723136'],
#   'id': '1645207439925723136',
#   'lang': 'en',
#   'created_at': '2023-04-09T23:29:54.000Z',
#   'text': '@Tesla I avoid buying anything made in Communist China.'},
#  {'edit_history_tweet_ids': ['1645207436821774338'],
#   'id': '1645207436821774338',
#   'lang': 'en',
#   'created_at': '2023-04-09T23:29:54.000Z',
#   'text': 'RT @TheTaijiNews: @ZoeSchiffer Sounds like a familiar Elon business practice. https://t.co/zdI3XSUKdV'},
#  {'edit_history_tweet_ids': ['1645207423282552833'],
#   'id': '1645207423282552833',
#   'lang': 'en',
#   'created_at': '2023-04-09T23:29:50.000Z',
#   'text': "@MooseHornRiver @EDUESPANA @Tesla I don't feel like explaining to Musk. He can easily explain himself. However, if liberals really care that much about China's disrespect for human life, then stop speaking against the CCP on camera while doing business under the table with them! It’s common sense."},
#  {'edit_history_tweet_ids': ['1645207420354920451'],
#   'id': '1645207420354920451',
#   'lang': 'en',
#   'created_at': '2023-04-09T23:29:50.000Z',
#   'text': 'RT @peterdog15: Giga Texas is cranking out &amp; shipping more Model Ys than ever with 50 per hour based on my time here today! Berlin beware!!…'},
#  {'edit_history_tweet_ids': ['1645207420132634624'],
#   'id': '1645207420132634624',
#   'lang': 'es',
#   'created_at': '2023-04-09T23:29:50.000Z',
#   'text': '@renacova Dicen los hijos de tesla qué el único que los puede tratar como pendejos es Samuel García'},
#  {'edit_history_tweet_ids': ['1645207415472680964'],
#   'id': '1645207415472680964',
#   'lang': 'es',
#   'created_at': '2023-04-09T23:29:48.000Z',
#   'text': 'Tesla construirá una nueva fábrica de baterías en China #Expansioncom https://t.co/aayHX4FZHP'},
#  {'edit_history_tweet_ids': ['1645207413081948166'],
#   'id': '1645207413081948166',
#   'lang': 'en',
#   'created_at': '2023-04-09T23:29:48.000Z',
#   'text': 'RT @CNN: The factory will be able to produce 10,000 Megapacks — very large batteries used to store utility-scale amounts of electricity — p…'},
#  {'edit_history_tweet_ids': ['1645207409428766722'],
#   'id': '1645207409428766722',
#   'lang': 'qme',
#   'created_at': '2023-04-09T23:29:47.000Z',
#   'text': '@nachodelaheysus @tearsintherain1 @ALi3NKAT @StarshipDock @PryZmRuleZZ @TeslaDarth @Michaeldoge420 @QuantumFekT @IamCelineMarie @TheKatsKid1 @lottkaren54 @Lionelclone1 @safferpsyche @SpadersNFTs @AndreMillaire @Rajtwittz @DogeAccept @musicphantom69 @jewel_gardener @d1dave123 @dawnheartLRPS @sofakingdoge2nd @kym_head @YeshuaisSavior @PiaPanda96 @PleiadesPlZ @YadiraRussell9 @YOUniverse999 @MaximoBanksy @bugaloo_2 @13dogecoin @boozelee86 @h_artsNcrafts @MarshaW15161057 @codehurtsbrain @elonmusk @Tesla @Tesla_Megapack @Grimezsz @dogecoin @Nike @SpaceCrystalZ @historydefined @HistoryInPics @NelsonMandela @YourHomeMars @SpaceX 🔥🔥🔥'},
#  {'edit_history_tweet_ids': ['1645207398943014912'],
#   'id': '1645207398943014912',
#   'lang': 'en',
#   'withheld': {'copyright': False, 'country_codes': ['ID']},
#   'created_at': '2023-04-09T23:29:45.000Z',
#   'text': 'RT @ValaAfshar: @elonmusk If you want to find the secrets of the universe, think in terms of energy, frequency and vibration.\n\n—Nikola Tesl…'},
#  {'edit_history_tweet_ids': ['1645207397324009475'],
#   'id': '1645207397324009475',
#   'lang': 'en',
#   'created_at': '2023-04-09T23:29:44.000Z',
#   'text': 'RT @tearsintherain1: @nachodelaheysus @ALi3NKAT @StarshipDock @PryZmRuleZZ @TeslaDarth @Michaeldoge420 @QuantumFekT @IamCelineMarie @TheKat…'},
#  {'edit_history_tweet_ids': ['1645207394467868673'],
#   'id': '1645207394467868673',
#   'lang': 'en',
#   'created_at': '2023-04-09T23:29:43.000Z',
#   'text': '@AHCapMgmt @Jones1CDSR @Tesla More than offset. One is a strategy that bears have overplayed. This is development in the right direction. I m more of a longer term investor. I see further into the future. The bears r just making noises. Price cuts spur adoption.'},
#  {'edit_history_tweet_ids': ['1645207368953737218'],
#   'id': '1645207368953737218',
#   'lang': 'en',
#   'created_at': '2023-04-09T23:29:37.000Z',
#   'text': '@nachodelaheysus @ALi3NKAT @StarshipDock @PryZmRuleZZ @TeslaDarth @Michaeldoge420 @QuantumFekT @IamCelineMarie @TheKatsKid1 @lottkaren54 @Lionelclone1 @safferpsyche @memesus77 @SpadersNFTs @AndreMillaire @Rajtwittz @DogeAccept @musicphantom69 @jewel_gardener @d1dave123 @dawnheartLRPS @sofakingdoge2nd @kym_head @YeshuaisSavior @PiaPanda96 @PleiadesPlZ @YadiraRussell9 @YOUniverse999 @MaximoBanksy @bugaloo_2 @13dogecoin @boozelee86 @h_artsNcrafts @MarshaW15161057 @codehurtsbrain @elonmusk @Tesla @Tesla_Megapack @Grimezsz @dogecoin @Nike @SpaceCrystalZ @historydefined @HistoryInPics @NelsonMandela @YourHomeMars @SpaceX I just come here for the free food 🥘'},
#  {'edit_history_tweet_ids': ['1645207361349361666'],
#   'id': '1645207361349361666',
#   'lang': 'en',
#   'created_at': '2023-04-09T23:29:36.000Z',
#   'text': '@Rebecca61017020 Reach out to Big Tesla for direct access to free signals, Trade Analysis and mentorship programs\n✅\n\nhttps://t.co/ixpv0wQ7AS'},
#  {'edit_history_tweet_ids': ['1645207361118674944'],
#   'id': '1645207361118674944',
#   'lang': 'en',
#   'created_at': '2023-04-09T23:29:36.000Z',
#   'text': 'Wow, Tesla faces class action privacy lawsuit, following startling revelations https://t.co/I3h9DFdGOi'},
#  {'edit_history_tweet_ids': ['1645207354969931777'],
#   'id': '1645207354969931777',
#   'lang': 'en',
#   'created_at': '2023-04-09T23:29:34.000Z',
#   'text': 'If Elon Musk is from South Africa, why is Tesla building a huge battery factory in China? Why not locate such project in an African country where the labor is cheap, and will create job for Africans?'},
#  {'edit_history_tweet_ids': ['1645207349533999104'],
#   'id': '1645207349533999104',
#   'lang': 'en',
#   'created_at': '2023-04-09T23:29:33.000Z',
#   'text': '@elonmusk Tesla is not Alian car ? 🤔'},
#  {'edit_history_tweet_ids': ['1645207349110669313'],
#   'id': '1645207349110669313',
#   'lang': 'en',
#   'created_at': '2023-04-09T23:29:33.000Z',
#   'text': 'RT @maskofbun: the fact that this concept art was supposed to be vash 1) shows how much he resembles tesla and aligns with the theory that…'},
#  {'edit_history_tweet_ids': ['1645207348548452354'],
#   'id': '1645207348548452354',
#   'lang': 'en',
#   'created_at': '2023-04-09T23:29:33.000Z',
#   'text': 'RT @nytimes: Tesla will build a factory in Shanghai to manufacture its large-scale energy-storage batteries known as the Megapack, the Chin…'},
#  {'edit_history_tweet_ids': ['1645207341858471942'],
#   'id': '1645207341858471942',
#   'lang': 'en',
#   'created_at': '2023-04-09T23:29:31.000Z',
#   'text': '@AryanPigkaw Do Einstein and Tesla have competing claims?'},
#  {'edit_history_tweet_ids': ['1645207339840987136'],
#   'id': '1645207339840987136',
#   'lang': 'en',
#   'created_at': '2023-04-09T23:29:30.000Z',
#   'text': 'RT @ZainulA36741500: @elonmusk @SawyerMerritt @Tesla Alerts crypto trader! They predicted that Bitcoin could fall to $5,000 levels in 2023.…'},
#  {'edit_history_tweet_ids': ['1645207339740418050'],
#   'id': '1645207339740418050',
#   'lang': 'en',
#   'created_at': '2023-04-09T23:29:30.000Z',
#   'text': 'RT @6abc: A Tesla owner filed a complaint accusing the company of allegedly violating California privacy laws, among other claims.  https:/…'},
#  {'edit_history_tweet_ids': ['1645207336602988544'],
#   'id': '1645207336602988544',
#   'lang': 'en',
#   'created_at': '2023-04-09T23:29:30.000Z',
#   'text': 'RT @Vespa_sa_gedli: Tesla -1.12%, Apple -0.33%, AI -26.34%, AMC -23.48%, Dow Jones Industrial -198 pts, Bitcoin 28,226 https://t.co/YM7CtC9…'},
#  {'edit_history_tweet_ids': ['1645207335005036544'],
#   'id': '1645207335005036544',
#   'lang': 'en',
#   'created_at': '2023-04-09T23:29:29.000Z',
#   'text': '@VivekGRamaswamy @elonmusk Megapack has nothing to do with EVs. It’s grid-scale battery storage. Also EVs for American consumers are made in America in Tesla’s factories in California, Nevada and Texas'},
#  {'edit_history_tweet_ids': ['1645207331242639363'],
#   'id': '1645207331242639363',
#   'lang': 'en',
#   'created_at': '2023-04-09T23:29:28.000Z',
#   'text': 'RT @SaycheeseDGTL: 😢 Former Tesla worker Owen Diaz was awarded $137M last year for dealing with racism on the job “The supervisor called hi…'},
#  {'edit_history_tweet_ids': ['1645207330466803714'],
#   'id': '1645207330466803714',
#   'lang': 'en',
#   'created_at': '2023-04-09T23:29:28.000Z',
#   'text': 'RT @IEEESpectrum: Developing cells for drones and air taxis is one way to achieve lightweight battery breakthroughs. This company has doubl…'},
#  {'edit_history_tweet_ids': ['1645207324993417216'],
#   'id': '1645207324993417216',
#   'lang': 'en',
#   'created_at': '2023-04-09T23:29:27.000Z',
#   'text': "RT @MuskUniversity: “Focus on signal over noise. A lot of companies get confused, they spend money on things that don't actually make the p…"},
#  {'edit_history_tweet_ids': ['1645207311894339585'],
#   'id': '1645207311894339585',
#   'lang': 'en',
#   'created_at': '2023-04-09T23:29:24.000Z',
#   'text': 'RT @DillonLoomis22: A lot of chatter about $TSLA growth rates slowing, demand falling, advertising needs etc. \n\nNot to oversimplify, but ca…'},
#  {'edit_history_tweet_ids': ['1645207308513812480'],
#   'id': '1645207308513812480',
#   'lang': 'en',
#   'created_at': '2023-04-09T23:29:23.000Z',
#   'text': 'RT @factchecking18: "We’ll also go after the Wall St short-sellers ... "\n\nSaid the $DOGE-pump-master 🤣\n\n#Musk \n#Tesla \n#Bitcoin https://t.c…'},
#  {'edit_history_tweet_ids': ['1645207305708015620'],
#   'id': '1645207305708015620',
#   'lang': 'en',
#   'created_at': '2023-04-09T23:29:22.000Z',
#   'text': '@MeniTsirbas @CornelyTristan @LucidMotors @Tesla not devoted to any company. $TSLA is my biggest investment followed by $LCID (distant 2nd) &amp; RIVN. love good engineering and making money. Just want to end this by saying, in 2023, a company with a stunning EV will make it. 86% auto market share still there for EVs to capture. GD'}]

# %% [markdown]
# - we access list indices using `[0]`, `[1]`->`[n]`

# %%
response.json()['data'][0]
# Out:
# {'edit_history_tweet_ids': ['1645207791890513920'],
#  'id': '1645207791890513920',
#  'lang': 'en',
#  'created_at': '2023-04-09T23:31:18.000Z',
#  'text': "@memesus77 @tearsintherain1 @ALi3NKAT @StarshipDock @PryZmRuleZZ @TeslaDarth @Michaeldoge420 @QuantumFekT @IamCelineMarie @TheKatsKid1 @lottkaren54 @Lionelclone1 @safferpsyche @SpadersNFTs @AndreMillaire @Rajtwittz @DogeAccept @musicphantom69 @jewel_gardener @d1dave123 @dawnheartLRPS @sofakingdoge2nd @kym_head @YeshuaisSavior @PiaPanda96 @PleiadesPlZ @YadiraRussell9 @YOUniverse999 @MaximoBanksy @bugaloo_2 @13dogecoin @boozelee86 @h_artsNcrafts @MarshaW15161057 @codehurtsbrain @elonmusk @Tesla @Tesla_Megapack @Grimezsz @dogecoin @Nike @SpaceCrystalZ @historydefined @HistoryInPics @NelsonMandela @YourHomeMars @SpaceX Is everyone scheduled and excited for bear hug Thursday it's coming up ya know....\n\nSigh 😕 https://t.co/btJxNITJuH"}

# %%
response.json()['data'][0]['text']
# Out:
# "@memesus77 @tearsintherain1 @ALi3NKAT @StarshipDock @PryZmRuleZZ @TeslaDarth @Michaeldoge420 @QuantumFekT @IamCelineMarie @TheKatsKid1 @lottkaren54 @Lionelclone1 @safferpsyche @SpadersNFTs @AndreMillaire @Rajtwittz @DogeAccept @musicphantom69 @jewel_gardener @d1dave123 @dawnheartLRPS @sofakingdoge2nd @kym_head @YeshuaisSavior @PiaPanda96 @PleiadesPlZ @YadiraRussell9 @YOUniverse999 @MaximoBanksy @bugaloo_2 @13dogecoin @boozelee86 @h_artsNcrafts @MarshaW15161057 @codehurtsbrain @elonmusk @Tesla @Tesla_Megapack @Grimezsz @dogecoin @Nike @SpaceCrystalZ @historydefined @HistoryInPics @NelsonMandela @YourHomeMars @SpaceX Is everyone scheduled and excited for bear hug Thursday it's coming up ya know....\n\nSigh 😕 https://t.co/btJxNITJuH"

# %% [markdown]
# - How should we store this data?

# %%
pd.DataFrame({
    'column_one':[1,2,3],
    'column_two':[4,5,6]
})
# Out:
#    column_one  column_two
# 0           1           4
# 1           2           5
# 2           3           6

# %%
df = pd.DataFrame()

for tweet in response.json()['data']:
    df = df.append(tweet, ignore_index=True)
    
df.head()
# Out:
# /var/folders/tz/z5m6fg7905g1b0zpb1g0vm680000gn/T/ipykernel_928/4043087574.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(tweet, ignore_index=True)
# /var/folders/tz/z5m6fg7905g1b0zpb1g0vm680000gn/T/ipykernel_928/4043087574.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(tweet, ignore_index=True)
# /var/folders/tz/z5m6fg7905g1b0zpb1g0vm680000gn/T/ipykernel_928/4043087574.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(tweet, ignore_index=True)
# /var/folders/tz/z5m6fg7905g1b0zpb1g0vm680000gn/T/ipykernel_928/4043087574.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(tweet, ignore_index=True)
# /var/folders/tz/z5m6fg7905g1b0zpb1g0vm680000gn/T/ipykernel_928/4043087574.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(tweet, ignore_index=True)
# /var/folders/tz/z5m6fg7905g1b0zpb1g0vm680000gn/T/ipykernel_928/4043087574.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(tweet, ignore_index=True)
# /var/folders/tz/z5m6fg7905g1b0zpb1g0vm680000gn/T/ipykernel_928/4043087574.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(tweet, ignore_index=True)
# /var/folders/tz/z5m6fg7905g1b0zpb1g0vm680000gn/T/ipykernel_928/4043087574.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(tweet, ignore_index=True)
# /var/folders/tz/z5m6fg7905g1b0zpb1g0vm680000gn/T/ipykernel_928/4043087574.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(tweet, ignore_index=True)
# /var/folders/tz/z5m6fg7905g1b0zpb1g0vm680000gn/T/ipykernel_928/4043087574.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(tweet, ignore_index=True)
# /var/folders/tz/z5m6fg7905g1b0zpb1g0vm680000gn/T/ipykernel_928/4043087574.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(tweet, ignore_index=True)
# /var/folders/tz/z5m6fg7905g1b0zpb1g0vm680000gn/T/ipykernel_928/4043087574.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(tweet, ignore_index=True)
# /var/folders/tz/z5m6fg7905g1b0zpb1g0vm680000gn/T/ipykernel_928/4043087574.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(tweet, ignore_index=True)
# /var/folders/tz/z5m6fg7905g1b0zpb1g0vm680000gn/T/ipykernel_928/4043087574.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(tweet, ignore_index=True)
# /var/folders/tz/z5m6fg7905g1b0zpb1g0vm680000gn/T/ipykernel_928/4043087574.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(tweet, ignore_index=True)
# /var/folders/tz/z5m6fg7905g1b0zpb1g0vm680000gn/T/ipykernel_928/4043087574.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(tweet, ignore_index=True)
# /var/folders/tz/z5m6fg7905g1b0zpb1g0vm680000gn/T/ipykernel_928/4043087574.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(tweet, ignore_index=True)
# /var/folders/tz/z5m6fg7905g1b0zpb1g0vm680000gn/T/ipykernel_928/4043087574.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(tweet, ignore_index=True)
# /var/folders/tz/z5m6fg7905g1b0zpb1g0vm680000gn/T/ipykernel_928/4043087574.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(tweet, ignore_index=True)
# /var/folders/tz/z5m6fg7905g1b0zpb1g0vm680000gn/T/ipykernel_928/4043087574.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(tweet, ignore_index=True)
# /var/folders/tz/z5m6fg7905g1b0zpb1g0vm680000gn/T/ipykernel_928/4043087574.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(tweet, ignore_index=True)
# /var/folders/tz/z5m6fg7905g1b0zpb1g0vm680000gn/T/ipykernel_928/4043087574.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(tweet, ignore_index=True)
# /var/folders/tz/z5m6fg7905g1b0zpb1g0vm680000gn/T/ipykernel_928/4043087574.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(tweet, ignore_index=True)
# /var/folders/tz/z5m6fg7905g1b0zpb1g0vm680000gn/T/ipykernel_928/4043087574.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(tweet, ignore_index=True)
# /var/folders/tz/z5m6fg7905g1b0zpb1g0vm680000gn/T/ipykernel_928/4043087574.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(tweet, ignore_index=True)
# /var/folders/tz/z5m6fg7905g1b0zpb1g0vm680000gn/T/ipykernel_928/4043087574.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(tweet, ignore_index=True)
# /var/folders/tz/z5m6fg7905g1b0zpb1g0vm680000gn/T/ipykernel_928/4043087574.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(tweet, ignore_index=True)
# /var/folders/tz/z5m6fg7905g1b0zpb1g0vm680000gn/T/ipykernel_928/4043087574.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(tweet, ignore_index=True)
# /var/folders/tz/z5m6fg7905g1b0zpb1g0vm680000gn/T/ipykernel_928/4043087574.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(tweet, ignore_index=True)
# /var/folders/tz/z5m6fg7905g1b0zpb1g0vm680000gn/T/ipykernel_928/4043087574.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(tweet, ignore_index=True)
# /var/folders/tz/z5m6fg7905g1b0zpb1g0vm680000gn/T/ipykernel_928/4043087574.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(tweet, ignore_index=True)
# /var/folders/tz/z5m6fg7905g1b0zpb1g0vm680000gn/T/ipykernel_928/4043087574.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(tweet, ignore_index=True)
# /var/folders/tz/z5m6fg7905g1b0zpb1g0vm680000gn/T/ipykernel_928/4043087574.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(tweet, ignore_index=True)
# /var/folders/tz/z5m6fg7905g1b0zpb1g0vm680000gn/T/ipykernel_928/4043087574.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(tweet, ignore_index=True)
# /var/folders/tz/z5m6fg7905g1b0zpb1g0vm680000gn/T/ipykernel_928/4043087574.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(tweet, ignore_index=True)
# /var/folders/tz/z5m6fg7905g1b0zpb1g0vm680000gn/T/ipykernel_928/4043087574.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(tweet, ignore_index=True)
# /var/folders/tz/z5m6fg7905g1b0zpb1g0vm680000gn/T/ipykernel_928/4043087574.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(tweet, ignore_index=True)
# /var/folders/tz/z5m6fg7905g1b0zpb1g0vm680000gn/T/ipykernel_928/4043087574.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(tweet, ignore_index=True)
# /var/folders/tz/z5m6fg7905g1b0zpb1g0vm680000gn/T/ipykernel_928/4043087574.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(tweet, ignore_index=True)
# /var/folders/tz/z5m6fg7905g1b0zpb1g0vm680000gn/T/ipykernel_928/4043087574.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(tweet, ignore_index=True)
# /var/folders/tz/z5m6fg7905g1b0zpb1g0vm680000gn/T/ipykernel_928/4043087574.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(tweet, ignore_index=True)
# /var/folders/tz/z5m6fg7905g1b0zpb1g0vm680000gn/T/ipykernel_928/4043087574.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(tweet, ignore_index=True)
# /var/folders/tz/z5m6fg7905g1b0zpb1g0vm680000gn/T/ipykernel_928/4043087574.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(tweet, ignore_index=True)
# /var/folders/tz/z5m6fg7905g1b0zpb1g0vm680000gn/T/ipykernel_928/4043087574.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(tweet, ignore_index=True)
# /var/folders/tz/z5m6fg7905g1b0zpb1g0vm680000gn/T/ipykernel_928/4043087574.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(tweet, ignore_index=True)
# /var/folders/tz/z5m6fg7905g1b0zpb1g0vm680000gn/T/ipykernel_928/4043087574.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(tweet, ignore_index=True)
# /var/folders/tz/z5m6fg7905g1b0zpb1g0vm680000gn/T/ipykernel_928/4043087574.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(tweet, ignore_index=True)
# /var/folders/tz/z5m6fg7905g1b0zpb1g0vm680000gn/T/ipykernel_928/4043087574.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(tweet, ignore_index=True)
# /var/folders/tz/z5m6fg7905g1b0zpb1g0vm680000gn/T/ipykernel_928/4043087574.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(tweet, ignore_index=True)
# /var/folders/tz/z5m6fg7905g1b0zpb1g0vm680000gn/T/ipykernel_928/4043087574.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(tweet, ignore_index=True)
# /var/folders/tz/z5m6fg7905g1b0zpb1g0vm680000gn/T/ipykernel_928/4043087574.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(tweet, ignore_index=True)
# /var/folders/tz/z5m6fg7905g1b0zpb1g0vm680000gn/T/ipykernel_928/4043087574.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(tweet, ignore_index=True)
# /var/folders/tz/z5m6fg7905g1b0zpb1g0vm680000gn/T/ipykernel_928/4043087574.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(tweet, ignore_index=True)
# /var/folders/tz/z5m6fg7905g1b0zpb1g0vm680000gn/T/ipykernel_928/4043087574.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(tweet, ignore_index=True)
# /var/folders/tz/z5m6fg7905g1b0zpb1g0vm680000gn/T/ipykernel_928/4043087574.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(tweet, ignore_index=True)
# /var/folders/tz/z5m6fg7905g1b0zpb1g0vm680000gn/T/ipykernel_928/4043087574.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(tweet, ignore_index=True)
# /var/folders/tz/z5m6fg7905g1b0zpb1g0vm680000gn/T/ipykernel_928/4043087574.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(tweet, ignore_index=True)
# /var/folders/tz/z5m6fg7905g1b0zpb1g0vm680000gn/T/ipykernel_928/4043087574.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(tweet, ignore_index=True)
# /var/folders/tz/z5m6fg7905g1b0zpb1g0vm680000gn/T/ipykernel_928/4043087574.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(tweet, ignore_index=True)
# /var/folders/tz/z5m6fg7905g1b0zpb1g0vm680000gn/T/ipykernel_928/4043087574.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(tweet, ignore_index=True)
# /var/folders/tz/z5m6fg7905g1b0zpb1g0vm680000gn/T/ipykernel_928/4043087574.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(tweet, ignore_index=True)
# /var/folders/tz/z5m6fg7905g1b0zpb1g0vm680000gn/T/ipykernel_928/4043087574.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(tweet, ignore_index=True)
# /var/folders/tz/z5m6fg7905g1b0zpb1g0vm680000gn/T/ipykernel_928/4043087574.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(tweet, ignore_index=True)
# /var/folders/tz/z5m6fg7905g1b0zpb1g0vm680000gn/T/ipykernel_928/4043087574.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(tweet, ignore_index=True)
# /var/folders/tz/z5m6fg7905g1b0zpb1g0vm680000gn/T/ipykernel_928/4043087574.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(tweet, ignore_index=True)
# /var/folders/tz/z5m6fg7905g1b0zpb1g0vm680000gn/T/ipykernel_928/4043087574.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(tweet, ignore_index=True)
# /var/folders/tz/z5m6fg7905g1b0zpb1g0vm680000gn/T/ipykernel_928/4043087574.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(tweet, ignore_index=True)
# /var/folders/tz/z5m6fg7905g1b0zpb1g0vm680000gn/T/ipykernel_928/4043087574.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(tweet, ignore_index=True)
# /var/folders/tz/z5m6fg7905g1b0zpb1g0vm680000gn/T/ipykernel_928/4043087574.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(tweet, ignore_index=True)
# /var/folders/tz/z5m6fg7905g1b0zpb1g0vm680000gn/T/ipykernel_928/4043087574.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(tweet, ignore_index=True)
# /var/folders/tz/z5m6fg7905g1b0zpb1g0vm680000gn/T/ipykernel_928/4043087574.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(tweet, ignore_index=True)
# /var/folders/tz/z5m6fg7905g1b0zpb1g0vm680000gn/T/ipykernel_928/4043087574.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(tweet, ignore_index=True)
# /var/folders/tz/z5m6fg7905g1b0zpb1g0vm680000gn/T/ipykernel_928/4043087574.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(tweet, ignore_index=True)
# /var/folders/tz/z5m6fg7905g1b0zpb1g0vm680000gn/T/ipykernel_928/4043087574.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(tweet, ignore_index=True)
# /var/folders/tz/z5m6fg7905g1b0zpb1g0vm680000gn/T/ipykernel_928/4043087574.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(tweet, ignore_index=True)
# /var/folders/tz/z5m6fg7905g1b0zpb1g0vm680000gn/T/ipykernel_928/4043087574.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(tweet, ignore_index=True)
# /var/folders/tz/z5m6fg7905g1b0zpb1g0vm680000gn/T/ipykernel_928/4043087574.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(tweet, ignore_index=True)
# /var/folders/tz/z5m6fg7905g1b0zpb1g0vm680000gn/T/ipykernel_928/4043087574.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(tweet, ignore_index=True)
# /var/folders/tz/z5m6fg7905g1b0zpb1g0vm680000gn/T/ipykernel_928/4043087574.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(tweet, ignore_index=True)
# /var/folders/tz/z5m6fg7905g1b0zpb1g0vm680000gn/T/ipykernel_928/4043087574.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(tweet, ignore_index=True)
# /var/folders/tz/z5m6fg7905g1b0zpb1g0vm680000gn/T/ipykernel_928/4043087574.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(tweet, ignore_index=True)
# /var/folders/tz/z5m6fg7905g1b0zpb1g0vm680000gn/T/ipykernel_928/4043087574.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(tweet, ignore_index=True)
# /var/folders/tz/z5m6fg7905g1b0zpb1g0vm680000gn/T/ipykernel_928/4043087574.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(tweet, ignore_index=True)
# /var/folders/tz/z5m6fg7905g1b0zpb1g0vm680000gn/T/ipykernel_928/4043087574.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(tweet, ignore_index=True)
# /var/folders/tz/z5m6fg7905g1b0zpb1g0vm680000gn/T/ipykernel_928/4043087574.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(tweet, ignore_index=True)
# /var/folders/tz/z5m6fg7905g1b0zpb1g0vm680000gn/T/ipykernel_928/4043087574.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(tweet, ignore_index=True)
# /var/folders/tz/z5m6fg7905g1b0zpb1g0vm680000gn/T/ipykernel_928/4043087574.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(tweet, ignore_index=True)
# /var/folders/tz/z5m6fg7905g1b0zpb1g0vm680000gn/T/ipykernel_928/4043087574.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(tweet, ignore_index=True)
# /var/folders/tz/z5m6fg7905g1b0zpb1g0vm680000gn/T/ipykernel_928/4043087574.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(tweet, ignore_index=True)
# /var/folders/tz/z5m6fg7905g1b0zpb1g0vm680000gn/T/ipykernel_928/4043087574.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(tweet, ignore_index=True)
# /var/folders/tz/z5m6fg7905g1b0zpb1g0vm680000gn/T/ipykernel_928/4043087574.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(tweet, ignore_index=True)
# /var/folders/tz/z5m6fg7905g1b0zpb1g0vm680000gn/T/ipykernel_928/4043087574.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(tweet, ignore_index=True)
# /var/folders/tz/z5m6fg7905g1b0zpb1g0vm680000gn/T/ipykernel_928/4043087574.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(tweet, ignore_index=True)
# /var/folders/tz/z5m6fg7905g1b0zpb1g0vm680000gn/T/ipykernel_928/4043087574.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(tweet, ignore_index=True)
# /var/folders/tz/z5m6fg7905g1b0zpb1g0vm680000gn/T/ipykernel_928/4043087574.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(tweet, ignore_index=True)
# /var/folders/tz/z5m6fg7905g1b0zpb1g0vm680000gn/T/ipykernel_928/4043087574.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(tweet, ignore_index=True)
# /var/folders/tz/z5m6fg7905g1b0zpb1g0vm680000gn/T/ipykernel_928/4043087574.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(tweet, ignore_index=True)
# /var/folders/tz/z5m6fg7905g1b0zpb1g0vm680000gn/T/ipykernel_928/4043087574.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(tweet, ignore_index=True)
# /var/folders/tz/z5m6fg7905g1b0zpb1g0vm680000gn/T/ipykernel_928/4043087574.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(tweet, ignore_index=True)
# /var/folders/tz/z5m6fg7905g1b0zpb1g0vm680000gn/T/ipykernel_928/4043087574.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(tweet, ignore_index=True)
#   edit_history_tweet_ids                   id lang                created_at  \
# 0  [1645207791890513920]  1645207791890513920   en  2023-04-09T23:31:18.000Z
# 1  [1645207779123118080]  1645207779123118080  qme  2023-04-09T23:31:15.000Z
# 2  [1645207775113523203]  1645207775113523203  qme  2023-04-09T23:31:14.000Z
# 3  [1645207772248653824]  1645207772248653824  qam  2023-04-09T23:31:14.000Z
# 4  [1645207760634626048]  1645207760634626048  und  2023-04-09T23:31:11.000Z
#
#                                                 text withheld
# 0  @memesus77 @tearsintherain1 @ALi3NKAT @Starshi...      NaN
# 1      @SawyerMerritt @Tesla https://t.co/r0f31PhSxb      NaN
# 2  @Nikola_Truth @blueskykites @TeslaUniverse_ @T...      NaN
# 3  @Tesla @elonmusk @NissanElectric @ford @Rivian...      NaN
# 4  @memesus77 @nachodelaheysus @ALi3NKAT @Starshi...      NaN

# %%
len(df)
# Out:
# 100
