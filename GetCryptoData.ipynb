# %%
import numpy as np
import pandas as pd

# %%
import yfinance as yf

# %%
data = yf.download(tickers='ETH-USD',period = '10d', interval='15m')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data
# Out:
#                             Open         High          Low        Close  \
# Datetime
# 2023-03-13 00:00:00  1590.831177  1594.115845  1586.674805  1591.342407
# 2023-03-13 00:15:00  1590.139160  1605.339966  1589.064331  1602.021606
# 2023-03-13 00:30:00  1604.436157  1626.175903  1599.681396  1626.175903
# 2023-03-13 00:45:00  1629.370728  1629.370728  1618.472778  1627.319458
# 2023-03-13 01:00:00  1623.133423  1623.133423  1614.823364  1615.470459
# ...                          ...          ...          ...          ...
# 2023-03-21 23:45:00  1801.469849  1801.815796  1801.469849  1801.815796
# 2023-03-22 00:00:00  1804.957031  1804.957031  1802.723999  1803.171509
# 2023-03-22 00:15:00  1802.905762  1803.693115  1800.756104  1800.840454
# 2023-03-22 00:30:00  1800.793091  1800.793091  1783.417358  1787.231567
# 2023-03-22 00:45:00  1786.082397  1791.306763  1786.082397  1791.272949
#
#                        Adj Close     Volume
# Datetime
# ...

# %%
import plotly.graph_objs as go

# %%
fig = go.Figure()

# Add Trace
fig.add_trace(go.Candlestick(x=data.index, 
                             open=data['Open'], 
                             high=data['High'], 
                             low=data['Low'], 
                             close=data['Close'], name='market data'))

# Update the layout
fig.update_layout(
    title='Bitcoin Live Stock Price evolution', yaxis_title= ' Stock Price (USD)')

# Update_X_Axis: Adding slider + Adding RangeSelect
fig.update_xaxes(
    title='Date', rangeslider_visible=True,
    rangeselector = dict(
        buttons = list([
                dict(count=15, label="15D", step="minute", stepmode="backward"),
                dict(count=45, label="45m", step="minute", stepmode="backward"),
                dict(count=1, label="HTD", step="hour", stepmode="todate"),
                dict(count=2, label="2h", step="hour", stepmode="backward"),
                dict(step='all')
            ])
        )
                
)

fig.show()
